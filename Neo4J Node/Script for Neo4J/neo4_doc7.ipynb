# %% [raw]
# ## Gathering Trepang at Karruwa (Little Vanderlin Island)
# Wararriji walba buyubuyuwa
# Kulu anka tharriba
# Wurrubanthalu
#
# Marnaji ndanmaya
# Kambala-wurrubala
# Kari-nguthundu
# Kari-ngamala

# %%
CREATE (:Word
    {
    Yanyuwa: 'walba',
    POS:'noun ',
    In_English: ' Clam shell. The clam belongs to the Rrumburriya clan. The clam shell is sung in the Rrumburriya Tiger Shark kujika as it leaves Vanderlin Rocks (Wurlma). Literally, walba means ‘genitals’, and the hinge of the clam shell is said to resemble the vagina.',
    Antonym: '',
    Synonym: '',
    Hypernymy: '',
    Hyponymy: '',
    Root: '',
    Stem: ''
    }
);
MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Gathering Trepang at Karruwa (Little Vanderlin Island)'}) , (b:Word {Yanyuwa: 'walba'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

CREATE (:Word
    {
    Yanyuwa: 'tharriba',
    POS:'noun ',
    In_English: ' Trepang, Holo-thuroidea species. Makassan loan word derived from taripang (‘ng’ loss has occurred). Trepang belongs the Wurdaliya clan.',
    Antonym: '',
    Synonym: '',
    Hypernymy: '',
    Hyponymy: '',
    Root: '',
    Stem: ''
    }
);
MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Gathering Trepang at Karruwa (Little Vanderlin Island)'}) , (b:Word {Yanyuwa: 'tharriba'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

CREATE (:Word
    {
    Yanyuwa: 'marnaji',
    POS:'adverb ',
    In_English: 'Here, at that place that is known well. This term can also take pronouns as a suffix.',
    Antonym: '',
    Synonym: '',
    Hypernymy: '',
    Hyponymy: '',
    Root: '',
    Stem: ''
    }
);
MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Gathering Trepang at Karruwa (Little Vanderlin Island)'}) , (b:Word {Yanyuwa: 'marnaji'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);
