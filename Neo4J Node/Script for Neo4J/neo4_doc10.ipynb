# %% [raw]
# ## Rain and Rib Bones of the Rainbow Serpent
#
# ### P1
# Wayka barra wayka nakari Marrinybul jiwini wabuda nayijan, Larlbangka baki Wawurranda na-wini awara, wabuda wurrbingu baji Burrumanmala, Mijirrmijirr barra kulu Milyiyula jibiya baji, aYukuwal a-jibiya baji kulu Manbakawaku jibiya baji.
#
# Wabarrangu li-wankala liwirdiwalangu ki-awarawu kaluyinbayaninya ki-nyirinja, limalbumalbu li-jibiya baji kaluyinbayaninya wabuda, nganiyaji kurdardi kalu-yinbayima wabuda kalinyamba-mirra li-malbumalbu liyikili-nganjiyu ki-wabudawu yinbayawu bawuji kalinyambamirra wiji nalu-wini barra liyimalbumalbungku Mamudibarrku, Mangayi, Mamudiyatha, Bunaja, Narnuwungkuwungku wiji barra kalinyamba-mirra warriya li-luku liyi-wirdinju ki-wabudawu bawuji.
#
# ### P2
# Milundurrala narnu-ruluruluwanka na-ngalki awara Wawukarriya bujimala jiwini baji jibiya baji wurrbingu barra, nya-mangaji awara jiwini dankurrdankurr ngulya kangka ki-bujimalawu nalalurr yiku jiwini barra baji, kujika barra ja-wingkayi nyala bajinju kari-ngamala barra nakari Lingajakarula.

# %% [raw]
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Rain and Rib Bones of the Rainbow Serpent'}) , (b:Word {Yanyuwa: 'awara'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Rain and Rib Bones of the Rainbow Serpent'}) , (b:Word {Yanyuwa: 'awara'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Rain and Rib Bones of the Rainbow Serpent'}) , (b:Word {Yanyuwa: 'nyala'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Rain and Rib Bones of the Rainbow Serpent'}) , (b:Word {Yanyuwa: 'jiwini'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Rain and Rib Bones of the Rainbow Serpent'}) , (b:Word {Yanyuwa: 'jiwini'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Rain and Rib Bones of the Rainbow Serpent'}) , (b:Word {Yanyuwa: 'nya-mangaji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Rain and Rib Bones of the Rainbow Serpent'}) , (b:Word {Yanyuwa: 'jibiya'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Rain and Rib Bones of the Rainbow Serpent'}) , (b:Word {Yanyuwa: 'jibiya'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Rain and Rib Bones of the Rainbow Serpent'}) , (b:Word {Yanyuwa: 'wabarrangu'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Rain and Rib Bones of the Rainbow Serpent'}) , (b:Word {Yanyuwa: 'kurdardi'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Rain and Rib Bones of the Rainbow Serpent'}) , (b:Word {Yanyuwa: 'wayka'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Rain and Rib Bones of the Rainbow Serpent'}) , (b:Word {Yanyuwa: 'na-ngalki'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Rain and Rib Bones of the Rainbow Serpent'}) , (b:Word {Yanyuwa: 'baji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Rain and Rib Bones of the Rainbow Serpent'}) , (b:Word {Yanyuwa: 'baji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Rain and Rib Bones of the Rainbow Serpent'}) , (b:Word {Yanyuwa: 'baji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Rain and Rib Bones of the Rainbow Serpent'}) , (b:Word {Yanyuwa: 'bawuji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Rain and Rib Bones of the Rainbow Serpent'}) , (b:Word {Yanyuwa: 'wiji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Rain and Rib Bones of the Rainbow Serpent'}) , (b:Word {Yanyuwa: 'barra'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Rain and Rib Bones of the Rainbow Serpent'}) , (b:Word {Yanyuwa: 'barra'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Rain and Rib Bones of the Rainbow Serpent'}) , (b:Word {Yanyuwa: 'barra'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Rain and Rib Bones of the Rainbow Serpent'}) , (b:Word {Yanyuwa: 'na-wini'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);

# %%
def extract_unique_words(sentence):
    words = sentence.replace('.', '').replace(',', '').lower().replace('‘', '').replace('’', '').split()
    unique_words = list(set(words))
    return unique_words

def extract_common_words(sentence1, sentence2):
    words1 = sentence1.replace('.', '').replace(',', '').lower().split()
    words2 = sentence2.replace('.', '').replace(',', '').lower().split()
    common_words = set(words1) & set(words2)
    return list(common_words)

def remove_words_from_list(word_list, words_to_remove):
    new_word_list = [word for word in word_list if word not in words_to_remove]
    return new_word_list

sentence1 = "Wayka barra wayka nakari Marrinybul jiwini wabuda nayijan, Larlbangka baki Wawurranda na-wini awara, wabuda wurrbingu baji Burrumanmala, Mijirrmijirr barra kulu Milyiyula jibiya baji, aYukuwal a-jibiya baji kulu Manbakawaku jibiya baji. Wabarrangu li-wankala liwirdiwalangu ki-awarawu kaluyinbayaninya ki-nyirinja, limalbumalbu li-jibiya baji kaluyinbayaninya wabuda, nganiyaji kurdardi kalu-yinbayima wabuda kalinyamba-mirra li-malbumalbu liyikili-nganjiyu ki-wabudawu yinbayawu bawuji kalinyambamirra wiji nalu-wini barra liyimalbumalbungku Mamudibarrku, Mangayi, Mamudiyatha, Bunaja, Narnuwungkuwungku wiji barra kalinyamba-mirra warriya li-luku liyi-wirdinju ki-wabudawu bawuji. Milundurrala narnu-ruluruluwanka na-ngalki awara Wawukarriya bujimala jiwini baji jibiya baji wurrbingu barra, nya-mangaji awara jiwini dankurrdankurr ngulya kangka ki-bujimalawu nalalurr yiku jiwini barra baji, kujika barra ja-wingkayi nyala bajinju kari-ngamala barra nakari Lingajakarula."
unique_words = extract_unique_words(sentence1)
#print(unique_words)

#print('\n')

sentence2 = 'wayka, wabarrangu, wankala, kurdardi, wumbiji, wudurru, marda, ngajarr, kaliku, na-alanji, arrkula, yalkuyi, nganambaji, wulala, kanymarda, arndaarnda, ma-bulawa, barra, ambuliyalu, wajbala, ngala, marni, jinangu, nganamba, mili, yurrulu, na-mulu, mulu, aluwalu, bawuji, wangantharra, li-wulu, luku, wurrirri, arrijila, na-ngulyanda, wiji, yukumantharra, baji, rarrinjarra, nya-mangaji, malbu, larla, yurrngumantha, mardumbarra, waykaliya, wunala, yumbulyumbulmantha, wakuku, wardali, buluki, yarraman, wabarrangu, mardumbarra, a-libaliba, ngayamantharra, a-muwarda, ngarrangarra, wujbi, mijimbangu, bardarda, na-wini, awara, ngabaya, na-ngalki, rrumburriya, jibiya, yiwa, nyarrku, na-ajinja, wunumbarra, minja, jabarri, juju, wangarni, ngaliba, jiwini, na-marnda, arnindawa, waraba, walkurr, dambulyama, wardi, marruwarra, ngarna, warringku, ngali, yuwu, yabi, wuka, yinku, anku, ma-rnayi, wulanga, baku, alunga, yimbalanga, rrarrku, narnu-yuwa, jarranymantharra, walba, tharriba, marnaji, walkurra, mijingu, jina, nyinga, kadikadi, ngulakari, ambirriju, a-wanthirl, marniwuthu, jakarda, jilili, na-wabija ,ngayulu, nyala, yarriwin, rarra, nganinya, kurdandu, bajingulaji, buyi'
common_words = extract_common_words(sentence1, sentence2)
print(common_words)

print('\n')

new_word_list = remove_words_from_list(unique_words, common_words)
print(new_word_list)
# Out:
# ['awara', 'nyala', 'jiwini', 'nya-mangaji', 'jibiya', 'wabarrangu', 'kurdardi', 'wayka', 'na-ngalki', 'baji', 'bawuji', 'wiji', 'barra', 'na-wini']
#
#
# ['marrinybul', 'ja-wingkayi', 'lingajakarula', 'yinbayawu', 'kalinyambamirra', 'li-malbumalbu', 'limalbumalbu', 'yiku', 'kalinyamba-mirra', 'milundurrala', 'bujimala', 'nalalurr', 'ayukuwal', 'kari-ngamala', 'kalu-yinbayima', 'ki-bujimalawu', 'nayijan', 'warriya', 'milyiyula', 'kujika', 'wurrbingu', 'ki-wabudawu', 'wawukarriya', 'li-wankala', 'liyikili-nganjiyu', 'kaluyinbayaninya', 'liyi-wirdinju', 'narnu-ruluruluwanka', 'nganiyaji', 'nakari', 'larlbangka', 'wabuda', 'liwirdiwalangu', 'mangayi', 'dankurrdankurr', 'kangka', 'li-luku', 'wawurranda', 'mamudibarrku', 'mijirrmijirr', 'nalu-wini', 'narnuwungkuwungku', 'manbakawaku', 'li-jibiya', 'ki-awarawu', 'ki-nyirinja', 'a-jibiya', 'bunaja', 'liyimalbumalbungku', 'burrumanmala', 'kulu', 'ngulya', 'mamudiyatha', 'bajinju', 'baki']

# %% [raw]
# bujimala, milyiyula, kujika, wawukarriya, narnu-ruluruluwanka, mangayi, dankurrdankurr, mamudibarrku, mijirrmijirr, narnuwungkuwungku, bunaja, burrumanmala, ngulya

# %% [raw]
# CREATE (:Word
#     {
#     Yanyuwa: 'bujimala',
#     POS:'noun ',
#     In_English: '1) rainbow; 2) Rain-bow Serpent; 3) whirlwind; 4) whirl-pool; 5) water spout; 6) cyclone. The Rainbow Serpent belongs to the Mambaliya-Wawukarriya clan, but there are also Rainbow Serpents that belong to the Rrumburriya clan. The name is sometimes used as a generic term for all python species or large venomous snakes, such as the taipan and king brown snake, which are seen to be living representations of the Rainbow Serpent. The coloured rain-bow in the sky is said to be the Rainbow Serpent travelling from waterhole to waterhole. There are two types of Rainbow Serpents: a main-land variety that has a tail like a snake, and a coastal or sea variety that has a tail like a dugong or whale. This term should never be said in a loud voice, and never used on the islands or the sea. When on the sea, the term janyka (rock or stone) is used instead of bujimala. It is also considered dangerous to point at a rainbow in the sky. This entity is sung in both the mainland and coastal kujika belonging to the Mambaliya-Wawukarriya clan. See also bulkurrimarri, warlungkarnarra, bayanangbayanang, mangundayarra, lhukunmantharra.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# CREATE (:Word
#     {
#     Yanyuwa: 'milyiyula',
#     POS:'noun ',
#     In_English: ' Gentle, light rain from the east in the wet season. This rain is associated with the Blue-Tongue Lizard Dreaming. Belongs to the Mambaliya-Wawukarriya clan.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# CREATE (:Word
#     {
#     Yanyuwa: 'kujika',
#     POS:'noun ',
#     In_English: '1) songline; 2) songline sung during ceremonial perform-ances. Each clan has a number of songlines, all sacred, some secret and sacred. Mambaliya-Wawukarriya clan have songlines including those that deal with the following Dreamings: Rain, Brolga, Crow, Wedge-Tailed Eagle, Whirlwind Rainbow Serpent, Rock Cod, Spotted Nightjar. Wuyaliya clan have song-lines including those that deal with following Dreamings: Dingo, Groper, Jabiru, Seven Sisters Stars, Barra-couta, Bushfire, Chicken Hawk. Rrumburriya clan have songlines including those that deal with the following Dreamings: Tiger Shark, kuju exclamation. 1) Sleep! 2) Go to sleep!',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# CREATE (:Word
#     {
#     Yanyuwa: 'wawukarriya',
#     POS:'noun ',
#     In_English: 'Clan name associated with the Mambaliya clan. Unlike other clan groups, the Mambaliya-Wawukarriya clan does not have any island country. Within their group, the term ‘Wawukarriya’ is used to describe those people associated with coastal areas, and ‘Mambaliya’ is used to describe those people associated with inland areas.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# CREATE (:Word
#     {
#     Yanyuwa: 'narnu-ruluruluwanka',
#     POS:'noun ',
#     In_English: 'Coastal country that consists of sandflats, saltpans and clay pans with small raised islets of scrubby vegetation. It is often the land between the land-ward side of the mangroves and the beginning of the actual savannah grasslands. This country can some-times extend up to 13 kilometres inland and is still often referred to as ‘sea country’.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# CREATE (:Word
#     {
#     Yanyuwa: 'mangayi',
#     POS:'noun ',
#     In_English: 'Name for a man from the Mambaliya-Wawukarriya clan. The name belongs to the Rain Dreaming. ',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# CREATE (:Word
#     {
#     Yanyuwa: 'dankurrdankurr',
#     POS:'noun ',
#     In_English: 'Red to yellow in colour.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# CREATE (:Word
#     {
#     Yanyuwa: 'mamudibarrku',
#     POS:'noun ',
#     In_English: 'Name for a man from the Mambaliya-Wawukarriya clan. The name belongs to the Whirlwind Stranger Rainbow Serpent Dreaming. ',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# CREATE (:Word
#     {
#     Yanyuwa: 'mijirrmijirr',
#     POS:'noun ',
#     In_English: '1) rainstorms in the wet season; 2) torrential rain. This rain belongs to the Mambaliya-Wawukarriya clan.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# CREATE (:Word
#     {
#     Yanyuwa: 'narnuwungkuwungku',
#     POS:'noun ',
#     In_English: 'Name for a man from the Mambaliya-Wawukarriya clan. The name belongs to the Rain Dreaming, in particular to the large, dark clouds of the wet season storms. Literally, the name means ‘blackness’.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# CREATE (:Word
#     {
#     Yanyuwa: 'bunaja',
#     POS:'noun',
#     In_English: 'Name for a man from the Mambaliya-Wawukarriya clan. The name is associated with the Wedge-Tailed Eagle Dreaming.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# CREATE (:Word
#     {
#     Yanyuwa: 'burrumanmala',
#     POS:'noun',
#     In_English: ' 1) torrential rain; 2) wet season rainstorms. This rain belongs to the Mambaliya-Wawukarriya clan.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# CREATE (:Word
#     {
#     Yanyuwa: 'ngulya',
#     POS:'noun ',
#     In_English: 'Blood.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );

# %%
MATCH (a:Word {Yanyuwa: 'wawukarriya'}) , (b:Subword {Yanyuwa: 'cm-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
MATCH (a:Word {Yanyuwa: 'mangayi'}) , (b:Subword {Yanyuwa: 'nya-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
MATCH (a:Word {Yanyuwa: 'dankurrdankurr'}) , (b:Subword {Yanyuwa: 'cm-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
MATCH (a:Word {Yanyuwa: 'mamudibarrku'}) , (b:Subword {Yanyuwa: 'nya-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
MATCH (a:Word {Yanyuwa: 'narnuwungkuwungku'}) , (b:Subword {Yanyuwa: 'nya-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
MATCH (a:Word {Yanyuwa: 'bunaja'}) , (b:Subword {Yanyuwa: 'nya-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
