# %% [raw]
# ## Incident at Rruwangkala [Black Rocks]
# CREATE (:Word
#     {
#     Yanyuwa: 'wayka',
#     POS:'noun',
#     In_English: '1) down; 2) down-stream; 3) down the river; 4) down to the sea.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'wayka'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'wabarrangu',
#     POS:'adverb',
#     In_English: '1) a long time ago; 2) long ago; 2) previously; 3) in past times; 4) in olden days.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'wabarrangu'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'wankala',
#     POS:'adjective',
#     In_English: '1) olden-time; 2) long ago; 3) ancestral (human).',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'wankala'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'kurdardi',
#     POS:'adjective and adverb',
#     In_English: '1) no; 2) not; 3) none; 4) not any more; 5) nothing.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'kurdardi'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'wumbiji',
#     POS:'adverb',
#     In_English: '1) centrally; 2) in the middle; 3) halfway.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'wumbiji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'wumbiji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'wudurru',
#     POS:'noun',
#     In_English: 'Food (generic)',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'wudurru'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'marda',
#     POS:'adverb',
#     In_English: '1) also; 2) too.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 3, Source_Paragraph: 1,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'marda'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'ngajarr',
#     POS:'noun ',
#     In_English: '1) gun; 2) rifle.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 3, Source_Paragraph: 1,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'ngajarr'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'ngajarr'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 4,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'ngajarr'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 5,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'ngajarr'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'kaliku',
#     POS:'noun ',
#     In_English: '1) calico; 2) canvas; 3) tarpaulin; 4) swag cover. This is an English loan word. Sometimes the word also sounds like kaluku. ',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 3, Source_Paragraph: 1,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'kaliku'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'na-alanji',
#     POS:'noun ',
#     In_English: '1) camp; 2) home.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'na-alanji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'arrkula',
#     POS:'adjective ',
#     In_English: ' 1) one (as a number); 2) being as one group; 3) being together.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'arrkula'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'yalkuyi',
#     POS:'adjective ',
#     In_English: '1) young adult man; 2) young adult woman.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'yalkuyi'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'nganambaji',
#     POS:'adverb ',
#     In_English: ' 1) that is the way you must do it; 2) like that you must do it. Specific, as of someone making sure that something is done correctly.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 2,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'nganambaji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'wulala',
#     POS:'adjective ',
#     In_English: 'To carry something on one’s head.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 2,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'wulala'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'kanymarda',
#     POS:'adjective ',
#     In_English: 'Two.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 3, Source_Paragraph: 2,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'kanymarda'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'arndaarnda',
#     POS:'adverb ',
#     In_English: '1) inside; 2) underground; 3) underneath. ',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 3, Source_Paragraph: 2,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'arndaarnda'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'ma-bulawa',
#     POS:'ma-bulawa',
#     In_English: ' Flour.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 3,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'ma-bulawa'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'barra',
#     POS:'noun ',
#     In_English: ' Westerly wind. A good wind when sailing a canoe, as it is gentle and constant. It is a wind of the wet season. It was also the wind that brought the Makassan sailors who used to gather trepang around the islands. ',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 4,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'barra'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'ambuliyalu',
#     POS:'adverb ',
#     In_English: 'Before (in time). ',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 4,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'ambuliyalu'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'wajbala',
#     POS:'noun ',
#     In_English: 'White person. English loan from ‘white fellow’. This is the more commonly used term in Yanyuwa; the alternative term for ‘white person’ is munanga, however it is more commonly used to speak of ‘white culture and ways of being’ more generally.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 4,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'wajbala'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'ngala',
#     POS:'adverb ',
#     In_English: '1) when; 2) while; 3) then. Can take a wide range of pronouns.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 4,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'ngala'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'marni',
#     POS:'adverb ',
#     In_English: ' 1) here, somewhere; 2) around here. Not as specific as marnaji; rather, a more colloquial form. This term can also take pronouns as a suffix.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 4,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'marni'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'jinangu',
#     POS:'pronoun ',
#     In_English: '1) (m) this specific masculine thing or male person; 2) (w) this specific masculine thing.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 4,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'jinangu'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'nganamba',
#     POS:'adverb ',
#     In_English: '1) that is the way to do it; 2) like that you do it. A general term, as of someone making a general observation.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 2,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'nganamba'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 4,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'nganamba'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'mili',
#     POS:'adverb ',
#     In_English: '1) more; 2) again; 3) also. ',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 5,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'mili'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'yurrulu',
#     POS:'adverb ',
#     In_English: '1) again; 2) more.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 5,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'yurrulu'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'na-mulu',
#     POS:'noun ',
#     In_English: ' 1) socket of a harpoon, where the point rests; 2) entrance, to a cave; 3) opening, of a hollow log coffin; 4) door; 5) mouthpiece, of a didjeridu. The stem of this word is mulu, ‘mouth’. ',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: 'mulu'
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 5,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'na-mulu'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'mulu',
#     POS:'noun',
#     In_English: 'mouth',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# MATCH (a:Word {Yanyuwa: 'na-mulu'}) , (b:Word {Yanyuwa: 'mulu'}),
# MERGE (a)-[r:Word_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'aluwalu',
#     POS:'pronoun ',
#     In_English: '1) to them; 2) to those people.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 5,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'aluwalu'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'bawuji',
#     POS:'adverb ',
#     In_English: ' 1) now; 2) don’t touch; 3) then when that was finished – as an introduction to another part of a story or event; 4) finished; 5) completed; 6) leave alone (with -ndi morpheme); 7) that is all; 8) ended or the end.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 5,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'bawuji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'wangantharra',
#     POS:'transitive verb',
#     In_English: '1) hitting; 2) shooting; 3) spearing; 4) striking; 5) fighting. The subjects of this verb may be human, animal or natural phenomena, such as light-ning.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: 'wangka'
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 5,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'wangantharra'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'li-wulu',
#     POS:'noun ',
#     In_English: '1) men; 2) Aboriginal men; 3) people.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 5,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'wanganli-wulutharra'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'luku',
#     POS:'adjective ',
#     In_English: 'Unfortunate person. Always used in phrase follow-ing warriya, ‘poor thing’. The term can express either real sadness, or it can be used in a joking way.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 5,  Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Word {Yanyuwa: 'luku'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);

# %%
CREATE (:Subword
    {
    Yanyuwa: 'cm-',
    Type: 'Prefix',
    Root: '',
    Usage: 'Entries that are followed by (cm-) are those for which the words in question can take a full or partial range of Yanyuwa prefixes.'
    }
);

MATCH (a:Word {Yanyuwa: 'arrkula'}) , (b:Subword {Yanyuwa: 'cm-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
MATCH (a:Word {Yanyuwa: 'wankala'}) , (b:Subword {Yanyuwa: 'cm-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
MATCH (a:Word {Yanyuwa: 'yalkuyi'}) , (b:Subword {Yanyuwa: 'cm-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
MATCH (a:Word {Yanyuwa: 'Kanymarda'}) , (b:Subword {Yanyuwa: 'cm-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
MATCH (a:Word {Yanyuwa: 'wajbala'}) , (b:Subword {Yanyuwa: 'cm-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
MATCH (a:Word {Yanyuwa: 'luku'}) , (b:Subword {Yanyuwa: 'cm-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);


CREATE (:Subword
    {
    Yanyuwa: 'ni-',
    Type: 'Prefix',
    Root: '',
    Usage: ''
    }
);
MATCH (a:Word {Yanyuwa: 'na-mulu'}) , (b:Subword {Yanyuwa: 'ni-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
