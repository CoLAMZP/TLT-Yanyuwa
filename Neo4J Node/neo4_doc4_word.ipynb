# %% [raw]
# ## Cave Spirit Men
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'nya-mangaji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'nya-mangaji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'nya-mangaji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'barra'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'barra'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 3, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'baji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'baji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'bawuji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'bawuji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
#
# CREATE (:Word
#     {
#     Yanyuwa: 'na-wini',
#     POS:'noun ',
#     In_English: '1) its name; 2) place name. Of country, plants, animals, plants, birds, fish.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'na-wini'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'na-wini'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'awara',
#     POS:'noun ',
#     In_English: '1) ground; 2) country; 3) place; 4) camp; 5) earth; 6) belong-ings; 7) possessions; 8) situation; 9) sea; 10) dirt.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'awara'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'awara'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'ngabaya',
#     POS:'noun ',
#     In_English: '1) spirit (generic); 2) ghost; 3) spirit of a dead person (generic); 4) white person (rare usage); 5) dead person; 6) Spirit Men Dreaming belonging to the Wurdaliya clan. The kujika for the Spirit Men Dreaming travels from Rocky (Kalalakinda), on the Foelsche River, and tracks north-northwest over to the coast to the northwest of the lower Robinson River; it then tracks north to Wanajararra islet, far to the northeast of Vanderlin Island. The kujika has a number of compli-cated arrangements, depending on the reason for its being sung and which lineage of the Yanyuwa–Garrwa Wurdaliya families are wanting to use it.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'ngabaya'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 3, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'ngabaya'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'na-ngalki',
#     POS:'noun ',
#     In_English: ' 1) distinct individual essence; 2) scent of a flower; 3) smell of an animal; 4) taste of food; 5) tune of song. That thing which marks indi-vidual identity. This word is some-times translated as ‘skin’. This is its most common usage and refers to the clan group of a person, animal, plant or fish. It is also the term used for ‘skin name’ or subsection name. All Dreamings carried ngalki that they left in the land and sea.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'na-ngalki'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'rrumburriya',
#     POS:'noun ',
#     In_English: ' Clan name. This clan is associated with three distinct geographical areas: one mainland, one coastal and one island group. During times of ceremony, however, all three come together and assist each other as one group.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'rrumburriya'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'jibiya',
#     POS:'adjective ',
#     In_English: ' 1) belonging to; 2) an inhabitant of; 3) someone whose birth place is; 4) someone whose spirit child came from a specific location. People, animals, plants, birds and food are all des-cribed as belonging to a specific location, either because they occur can there, are often found or seen there, or they are Dreaming there.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'jibiya'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'jibiya'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'yiwa',
#     POS:'pronoun ',
#     In_English: ' 1) (m&w) he; 2) (m&w) him; 3) (m) it.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'yiwa'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'nyarrku',
#     POS:'pronoun ',
#     In_English: ' 1) (m) that other masculine thing; 2) (m&w) that other man; 3) (m&w) another man.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'nyarrku'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'na-ajinja',
#     POS:'noun ',
#     In_English: ' 1) cave; 2) rock shelter.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'na-ajinja'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'wunumbarra',
#     POS:'adverb ',
#     In_English: '1) near; 2) close.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'wunumbarra'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'minja',
#     POS:'adverb ',
#     In_English: ' 1) only, for no parti-cular reason; 2) just; 3) for a little while. ',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'minja'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'jabarri',
#     POS:'adverb ',
#     In_English: '1) changing over; 2) taking turns; 3) turn-and-turn about.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'jabarri'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'juju',
#     POS:'adverb ',
#     In_English: ' 1) a long way; 2) a long time.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'juju'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'wangarni',
#     POS:'adverb ',
#     In_English: '1) nearby; 2) close. ',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'wangarni'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'ngaliba',
#     POS:'adverb ',
#     In_English: ' 1) to; 2) all the way to.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'ngaliba'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'jiwini',
#     POS:'intransitive verb',
#     In_English: '(m&w) He is being.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 3, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'jiwini'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'na-marnda',
#     POS:'ni-',
#     In_English: 'Footprint of an animal.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 3, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'na-marnda'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'arnindawa',
#     POS:'adverb',
#     In_English: '1) along the coast; 2) lower down; 3) towards the bottom; 4) next one down.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 3, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'arnindawa'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'waraba',
#     POS:'adjective and adverb',
#     In_English: ' 1) no; 2) not; 3) none; 4) not any more; 5) nothing. Negative particle that occurs with noun having referent-marking, to mean ‘none of’. ',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}) , (b:Word {Yanyuwa: 'waraba'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);

# %%
CREATE (:Subword
    {
    Yanyuwa: 'nanda-',
    Type: 'prefix',
    Root: '',
    Usage: ''
    }
);

CREATE (:Subword
    {
    Yanyuwa: 'nu-',
    Type: 'prefix',
    Root: '',
    Usage: ''
    }
);

CREATE (:Subword
    {
    Yanyuwa: 'ma-',
    Type: 'prefix',
    Root: '',
    Usage: ''
    }
);

CREATE (:Subword
    {
    Yanyuwa: 'niwa-',
    Type: 'prefix',
    Root: '',
    Usage: ''
    }
);

CREATE (:Subword
    {
    Yanyuwa: 'nalu-',
    Type: 'prefix',
    Root: '',
    Usage: ''
    }
);

MATCH (a:Word {Yanyuwa: 'jibiya'}) , (b:Subword {Yanyuwa: 'cm-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);

MATCH (a:Word {Yanyuwa: 'na-marnda'}) , (b:Subword {Yanyuwa: 'ni-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);

MATCH (a:Word {Yanyuwa: 'na-wini'}) , (b:Subword {Yanyuwa: 'ma-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
MATCH (a:Word {Yanyuwa: 'na-wini'}) , (b:Subword {Yanyuwa: 'nu-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
MATCH (a:Word {Yanyuwa: 'na-wini'}) , (b:Subword {Yanyuwa: 'nanda-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
MATCH (a:Word {Yanyuwa: 'na-wini'}) , (b:Subword {Yanyuwa: 'ni-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);

MATCH (a:Word {Yanyuwa: 'na-ngalki'}) , (b:Subword {Yanyuwa: 'ni-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
MATCH (a:Word {Yanyuwa: 'na-ngalki'}) , (b:Subword {Yanyuwa: 'nanda-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
MATCH (a:Word {Yanyuwa: 'na-ngalki'}) , (b:Subword {Yanyuwa: 'niwa-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
MATCH (a:Word {Yanyuwa: 'na-ngalki'}) , (b:Subword {Yanyuwa: 'nalu-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
