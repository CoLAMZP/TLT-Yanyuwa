# %% [raw]
# # Rock Cod
#
# ##### P1
# Jarrka barra na-wini awara namulkan barra liyi-Wawukarriyawu Wangkuwa na-yijan ka-arri baji namba ambuliyalu ka-wingka karingamala nakari Lurriyarri nyamangaji Kurdarrku kilu-jujunma yiku ki-Wangkuwawu waykaliya kianthalu, ambirriju Wangkuwa kawingka waykaliya kilu-wundarrba Wangkuwala, kumba-wundarrba nanda-wini baji bajingu Thayinda, nakari Thayinda Rudanbabanda, bajingu Wikalwikala kimaramanda nya-mangaji awara bajingu yibandayarra Lidambuwa ka-arri baji kulu bajingu, kawingka kari-nguthunda nakari Lidambuwa yawurndu barra, Lidambuwa na-wini awara kianthaa barra, Wangkuwa kawingka ka-wundirri ka-yibanda Liwarriya mulkanda barra, kiluyibarra jaynyka baji, ka-wingka kulu kila-kala biwali baki kinybutha ki-kujikala jibiya Jarrka.
#
# Na-yurrngu baji Jarrka mabin jiwini ngaliwa Wangkuwa kangalba arndaarnda ki-awarala, nyamangaji mabin na-mulu yiku kiWangkuwawu Dirdikurru jiwini nungku-mulungka barra jilukunkunmanji wabuda, wurrbingu baji jilu-mulumanji wabuda wurluburlu nyiki-nganji barra. Wangkuwa na-yurrngu bawuji.

# %% [raw]
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'dirdikurru'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'ambuliyalu'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'bawuji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'kinybutha'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'wurluburlu'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'jibiya'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'awara'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'awara'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'baji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'baji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'biwali'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'na-mulu'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'waykaliya'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'bajingu'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'wangkuwa'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'wangkuwa'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'barra'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'barra'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'nya-mangaji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'yibandayarra'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'na-wini'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'arndaarnda'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'jiwini'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'ambirriju'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Rock Cod'}) , (b:Word {Yanyuwa: 'kurdarrku'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);

# %%
def extract_unique_words(sentence):
    words = sentence.replace('.', '').replace(',', '').lower().replace('‘', '').replace('’', '').split()
    unique_words = list(set(words))
    return unique_words

def extract_common_words(sentence1, sentence2):
    words1 = sentence1.replace('.', '').replace(',', '').lower().split()
    words2 = sentence2.replace('.', '').replace(',', '').lower().split()
    common_words = set(words1) & set(words2)
    return list(common_words)

def remove_words_from_list(word_list, words_to_remove):
    new_word_list = [word for word in word_list if word not in words_to_remove]
    return new_word_list

sentence1 = 'Jarrka barra na-wini awara namulkan barra liyi-Wawukarriyawu Wangkuwa na-yijan ka-arri baji namba ambuliyalu ka-wingka karingamala nakari Lurriyarri nyamangaji Kurdarrku kilu-jujunma yiku ki-Wangkuwawu waykaliya kianthalu, ambirriju Wangkuwa kawingka waykaliya kilu-wundarrba Wangkuwala, kumba-wundarrba nanda-wini baji bajingu Thayinda, nakari Thayinda Rudanbabanda, bajingu Wikalwikala kimaramanda nya-mangaji awara bajingu yibandayarra Lidambuwa ka-arri baji kulu bajingu, kawingka kari-nguthunda nakari Lidambuwa yawurndu barra, Lidambuwa na-wini awara kianthaa barra, Wangkuwa kawingka ka-wundirri ka-yibanda Liwarriya mulkanda barra, kiluyibarra jaynyka baji, ka-wingka kulu kila-kala biwali baki kinybutha ki-kujikala jibiya Jarrka. Na-yurrngu baji Jarrka mabin jiwini ngaliwa Wangkuwa kangalba arndaarnda ki-awarala, nyamangaji mabin na-mulu yiku kiWangkuwawu Dirdikurru jiwini nungku-mulungka barra jilukunkunmanji wabuda, wurrbingu baji jilu-mulumanji wabuda wurluburlu nyiki-nganji barra. Wangkuwa na-yurrngu bawuji.'
unique_words = extract_unique_words(sentence1)

sentence2 = 'wayka, wabarrangu, wankala, kurdardi, wumbiji, wudurru, marda, ngajarr, kaliku, na-alanji, arrkula, yalkuyi, nganambaji, wulala, kanymarda, arndaarnda, ma-bulawa, barra, ambuliyalu, wajbala, ngala, marni, jinangu, nganamba, mili, yurrulu, na-mulu, mulu, aluwalu, bawuji, wangantharra, li-wulu, luku, wurrirri, arrijila, na-ngulyanda, wiji, yukumantharra, baji, rarrinjarra, nya-mangaji, malbu, larla, yurrngumantha, mardumbarra, waykaliya, wunala, yumbulyumbulmantha, wakuku, wardali, buluki, yarraman, wabarrangu, mardumbarra, a-libaliba, ngayamantharra, a-muwarda, ngarrangarra, wujbi, mijimbangu, bardarda, na-wini, awara, ngabaya, na-ngalki, rrumburriya, jibiya, yiwa, nyarrku, na-ajinja, wunumbarra, minja, jabarri, juju, wangarni, ngaliba, jiwini, na-marnda, arnindawa, waraba, walkurr, dambulyama, wardi, marruwarra, ngarna, warringku, ngali, yuwu, yabi, wuka, yinku, anku, ma-rnayi, wulanga, baku, alunga, yimbalanga, rrarrku, narnu-yuwa, jarranymantharra, walba, tharriba, marnaji, walkurra, mijingu, jina, nyinga, kadikadi, ngulakari, ambirriju, a-wanthirl, marniwuthu, jakarda, jilili, na-wabija ,ngayulu, nyala, yarriwin, rarra, nganinya, kurdandu, bajingulaji, buyi, bujimala, milyiyula, kujika, wawukarriya, narnu-ruluruluwanka, mangayi, dankurrdankurr, mamudibarrku, mijirrmijirr, narnuwungkuwungku, bunaja, burrumanmala, ngulya, dirdikurru, kinybutha, wurluburlu, biwali, bajingu, wangkuwa, yibandayarra, kurdarrku, rawurrki, yarrambawaja, nankawa, wurralngu, ruthu, wirrankayarra, walayungkuma, wurnda, yurlkanjurlkan, marringaya'
common_words = extract_common_words(sentence1, sentence2)
print(common_words)

print('\n')

new_word_list = remove_words_from_list(unique_words, common_words)
print(new_word_list)
# Out:
# ['dirdikurru', 'ambuliyalu', 'bawuji', 'kinybutha', 'wurluburlu', 'jibiya', 'awara', 'baji', 'biwali', 'na-mulu', 'waykaliya', 'bajingu', 'wangkuwa', 'barra', 'nya-mangaji', 'yibandayarra', 'na-wini', 'arndaarnda', 'jiwini', 'ambirriju', 'kurdarrku']
#
#
# ['ka-yibanda', 'liwarriya', 'yiku', 'karingamala', 'kilu-jujunma', 'kulu', 'kianthalu', 'ka-arri', 'ki-awarala', 'kangalba', 'kianthaa', 'kari-nguthunda', 'baki', 'mabin', 'kiluyibarra', 'thayinda', 'nanda-wini', 'jilukunkunmanji', 'wurrbingu', 'jarrka', 'ngaliwa', 'ki-kujikala', 'liyi-wawukarriyawu', 'nakari', 'na-yijan', 'ki-wangkuwawu', 'kawingka', 'kumba-wundarrba', 'kimaramanda', 'mulkanda', 'nungku-mulungka', 'nyiki-nganji', 'lurriyarri', 'nyamangaji', 'kilu-wundarrba', 'kila-kala', 'jaynyka', 'ka-wundirri', 'yawurndu', 'wikalwikala', 'wangkuwala', 'na-yurrngu', 'wabuda', 'namulkan', 'ka-wingka', 'rudanbabanda', 'namba', 'lidambuwa', 'kiwangkuwawu', 'jilu-mulumanji']

# %% [raw]
# dirdikurru, kinybutha, wurluburlu, biwali, bajingu, wangkuwa, yibandayarra, kurdarrku

# %% [raw]
# CREATE (:Word
#     {
#     Yanyuwa: 'dirdikurru',
#     POS:'noun ',
#     In_English: ' Olive python, Liasis olivaceus. The olive python belongs to the Mambaliya-Wawukarriya clan. This snake is sung in the mainland and coastal kujika of the Mambaliya-Wawukarriya clan.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# CREATE (:Word
#     {
#     Yanyuwa: 'kinybutha',
#     POS:'noun ',
#     In_English: ' Little red flying-fox, Pteropus scapulatus. Belongs to the Mambaliya-Wawukarriya clan. This flying-fox is sung in both the main-land and coastal kujika of the Mambaliya-Wawukarriya clan and also in the Rrumburriya Tiger Shark kujika.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# CREATE (:Word
#     {
#     Yanyuwa: 'wurluburlu',
#     POS:'adverb ',
#     In_English: ' 1) water at a high level; 2) high tide; 3) full; 4) satisfied.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# CREATE (:Word
#     {
#     Yanyuwa: 'biwali',
#     POS:'noun ',
#     In_English: '1) northern brushtail possum, Trichosurus arnhemensis; 2) possums and phascogales (generic). This possum belongs to the Mambaliya-Wawukarriya clan. The biwali was once eaten, and the fur would be plucked from its body, processed and spun into a soft string that was used for making both male and female pubic coverings. The possum’s fur, once plucked from its body, was placed somewhere free from breezes, where it was pounded with a stick on a log until the fur was quite matted. It was then spun using a spindle. The possum is sung in both the mainland and coastal kujika belonging to the Mambaliya-',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# CREATE (:Word
#     {
#     Yanyuwa: 'bajingu',
#     POS:'adverb ',
#     In_English: ' 1) from there; 2) after that.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# CREATE (:Word
#     {
#     Yanyuwa: 'wangkuwa',
#     POS:'noun ',
#     In_English: 'Estuarine rock cod, Epinephelus undulatostriatus. Belongs to the Mambaliya-Wawukarriya clan and the country of Jarrka. This fish is sung in the coastal Mambaliya-Wawukarriya kujika.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# CREATE (:Word
#     {
#     Yanyuwa: 'yibandayarra',
#     POS:'intransitive verb',
#     In_English: '1) arriving; 2) sitting down; 3) land-ing; 4) berthing.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
#
# CREATE (:Word
#     {
#     Yanyuwa: 'kurdarrku',
#     POS:'noun ',
#     In_English: ' 1) brolga, Grus rubicunda; 2) eastern saurus crane, Grus antigone. Belongs to the Mambaliya-Wawukarriya clan. The brolga is sung in the mainland and coastal Mambaliya-Wawukarriya kujika, and also in the Rrumburriya Tiger Shark kujika. ',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
