# %% [raw]
# ## Burying the Dead
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Burying the Dead'}) , (b:Word {Yanyuwa: 'ambuliyalu'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Burying the Dead'}) , (b:Word {Yanyuwa: 'wabarrangu'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Burying the Dead'}) , (b:Word {Yanyuwa: 'kurdardi'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Burying the Dead'}) , (b:Word {Yanyuwa: 'wayka'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Burying the Dead'}) , (b:Word {Yanyuwa: 'ngala'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Burying the Dead'}) , (b:Word {Yanyuwa: 'bawuji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'wurrirri',
#     POS:'adjective ',
#     In_English: ' 1) big; 2) great; 3) important; 4) adult; 5) mature.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Burying the Dead'}) , (b:Word {Yanyuwa: 'wurrirri'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'arrijila',
#     POS:'adverb ',
#     In_English: '1) hanging down; 2) placed above.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Burying the Dead'}) , (b:Word {Yanyuwa: 'arrijila'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'na-ngulyanda',
#     POS:'noun ',
#     In_English: ' 1) bones of a dead person; 2) shell of a sea turtle; 3) bones of any animal.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Burying the Dead'}) , (b:Word {Yanyuwa: 'na-ngulyanda'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'wiji',
#     POS:'adverb ',
#     In_English: ' 1) all inclusively; 2) everyone; 3) completely; 4) every-thing.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Burying the Dead'}) , (b:Word {Yanyuwa: 'wiji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'yukumantharra',
#     POS:'transitive verb ',
#     In_English: '1) looking after; 2) watching over.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Burying the Dead'}) , (b:Word {Yanyuwa: 'yukumantharra'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'baji',
#     POS:'adverb ',
#     In_English: ' 1) there, at that place we all know; 2) then, at that time we have agreed upon. This term can also take pronouns as a suffix.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Burying the Dead'}) , (b:Word {Yanyuwa: 'baji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 3,  Source: 'Burying the Dead'}) , (b:Word {Yanyuwa: 'baji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 4,  Source: 'Burying the Dead'}) , (b:Word {Yanyuwa: 'baji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'rarrinjarra',
#     POS:'intransitive verb',
#     In_English: '1) cry-ing; 2) being sad; 3) being sorry for; 4) mourning; 5) wailing.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Burying the Dead'}) , (b:Word {Yanyuwa: 'rarrinjarra'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'nya-mangaji',
#     POS:'pronoun ',
#     In_English: '1) (m&w) that specific male person; 2) (m) that specific masculine thing.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 3,  Source: 'Burying the Dead'}) , (b:Word {Yanyuwa: 'nya-mangaji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 4,  Source: 'Burying the Dead'}) , (b:Word {Yanyuwa: 'nya-mangaji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'malbu',
#     POS:'noun ',
#     In_English: ' Old man.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 3,  Source: 'Burying the Dead'}) , (b:Word {Yanyuwa: 'malbu'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'larla',
#     POS:'noun ',
#     In_English: 'Hollow log coffin. Made from a hollow length of messmate tree trunk, usually between 1.5 and 2 metres long. The bones of deceased men and women were once put into such coffins. The outside of the coffin was decorated with sacred Dreaming designs significant to the individual. On completion, the coffin was dis-played publically in the camp and then taken to the country of the dead person. Each clan has an area of land that was used for the placement of log coffins; these areas are highly restrict-ed places. It was the jungkayi or guardians for the dead person who cut and decorated the hollow log coffin. A person who made a log coffin was said to own it. Two old men, Jerry Brown Ngarnawakajaya and Old Rory Karrmula, made the last log coffin in 1982. The bones of Billy Hooker Mangayi, the last Yanyuwa rainmaker, were placed into a log coffin. This coffin was prepared during the performance of a Kulyu-kulyu ceremony and was decorated with Long-Necked Turtle, Crow and Wedge-Tailed Eagle Dreaming designs.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 3,  Source: 'Burying the Dead'}) , (b:Word {Yanyuwa: 'larla'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'yurrngumantha',
#     POS:'adverb ',
#     In_English: '1) continu-ally; 2) all the time; 3) all the way.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 4,  Source: 'Burying the Dead'}) , (b:Word {Yanyuwa: 'yurrngumantha'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);

# %%
MATCH (a:Word {Yanyuwa: 'wurrirri'}) , (b:Subword {Yanyuwa: 'cm-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);

MATCH (a:Word {Yanyuwa: 'na-ngulyanda'}) , (b:Subword {Yanyuwa: 'ni-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);


CREATE (:Subword
    {
    Yanyuwa: 'nya-',
    Type: 'Prefix',
    Root: '',
    Usage: ''
    }
);

CREATE (:Subword
    {
    Yanyuwa: 'li-',
    Type: 'Prefix',
    Root: '',
    Usage: ''
    }
);
MATCH (a:Word {Yanyuwa: 'malbu'}) , (b:Subword {Yanyuwa: 'nya-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
MATCH (a:Word {Yanyuwa: 'malbu'}) , (b:Subword {Yanyuwa: 'li-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
