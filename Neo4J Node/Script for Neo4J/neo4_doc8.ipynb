# %% [raw]
# ## Mud Crab

# %% [raw]
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Mud Crab'}) , (b:Word {Yanyuwa: 'barra'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Mud Crab'}) , (b:Word {Yanyuwa: 'jiwini'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Mud Crab'}) , (b:Word {Yanyuwa: 'na-wini'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Mud Crab'}) , (b:Word {Yanyuwa: 'awara'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 3, Source_Paragraph: 1,  Source: 'Mud Crab'}) , (b:Word {Yanyuwa: 'baji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Mud Crab'}) , (b:Word {Yanyuwa: 'nya-mangaji'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Mud Crab'}) , (b:Word {Yanyuwa: 'wayka'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Mud Crab'}) , (b:Word {Yanyuwa: 'arnindawa'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# MATCH (a:Sentence {Sequence_number: 5, Source_Paragraph: 1,  Source: 'Mud Crab'}) , (b:Word {Yanyuwa: 'jibiya'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);

# %% [raw]
# CREATE (:Word
#     {
#     Yanyuwa: 'walkurra',
#     POS:'adjective ',
#     In_English: '1) big; 2) large; 3) important; 4) significant; 5) great.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Mud Crab'}) , (b:Word {Yanyuwa: 'walkurra'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
#
# CREATE (:Word
#     {
#     Yanyuwa: 'mijingu',
#     POS:'noun ',
#     In_English: '1) rocky boulders; 2) rock monoliths.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Mud Crab'}) , (b:Word {Yanyuwa: 'mijingu'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'jina',
#     POS:'pronoun ',
#     In_English: '1) (m) this specific male person or masculine thing; 2) (w) this masculine thing.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Mud Crab'}) , (b:Word {Yanyuwa: 'jina'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 6, Source_Paragraph: 1,  Source: 'Mud Crab'}) , (b:Word {Yanyuwa: 'jina'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'nyinga',
#     POS:'noun ',
#     In_English: ' 1) crab (generic); 2) mud crab (generic). Belongs to the Rrumburriya clan. The mud crab is sung in the Rrumburriya Tiger Shark kujika as it tracks down the Wearyan River.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Mud Crab'}) , (b:Word {Yanyuwa: 'nyinga'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 5, Source_Paragraph: 1,  Source: 'Mud Crab'}) , (b:Word {Yanyuwa: 'nyinga'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'kadikadi',
#     POS:'noun ',
#     In_English: 'Young of the giant mud crab, Scylla serrata. The mud crab belongs to the Rrumburriya clan.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 3, Source_Paragraph: 1,  Source: 'Mud Crab'}) , (b:Word {Yanyuwa: 'kadikadi'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
# MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Mud Crab'}) , (b:Word {Yanyuwa: 'kadikadi'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'ngulakari',
#     POS:'adverb ',
#     In_English: ' 1) behind; 2) back further .',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Mud Crab'}) , (b:Word {Yanyuwa: 'ngulakari'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'ambirriju',
#     POS:'adverb ',
#     In_English: ' 1) going in the lead; 2) going in front of; 3) ahead.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Mud Crab'}) , (b:Word {Yanyuwa: 'ambirriju'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'a-wanthirl',
#     POS:'noun ',
#     In_English: ' Female giant mud crab, Scylla serrata. The mud crab belongs to the Rrumburriya clan and is a Dreaming at Nungkawa-thungka in Victoria Bay on Vanderlin Island.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Mud Crab'}) , (b:Word {Yanyuwa: 'a-wanthirl'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'marniwuthu',
#     POS:'adverb ',
#     In_English: 'This way.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 6, Source_Paragraph: 1,  Source: 'Mud Crab'}) , (b:Word {Yanyuwa: 'marniwuthu'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);
#
# CREATE (:Word
#     {
#     Yanyuwa: 'jakarda',
#     POS:'adjective ',
#     In_English: ' 1) many; 2) plenty; 3) a lot of.',
#     Antonym: '',
#     Synonym: '',
#     Hypernymy: '',
#     Hyponymy: '',
#     Root: '',
#     Stem: ''
#     }
# );
# MATCH (a:Sentence {Sequence_number: 6, Source_Paragraph: 1,  Source: 'Mud Crab'}) , (b:Word {Yanyuwa: 'jakarda'}),
# MERGE (a)-[r:Sentence_Word_Relation]->(b);

# %% [raw]
# MATCH (a:Word {Yanyuwa: 'walkurra'}) , (b:Subword {Yanyuwa: 'cm-'}),
# MERGE (a)-[r:Word_Subword_Relation]->(b);
#
# MATCH (a:Word {Yanyuwa: 'jakarda'}) , (b:Subword {Yanyuwa: 'cm-'}),
# MERGE (a)-[r:Word_Subword_Relation]->(b);
#
# MATCH (a:Word {Yanyuwa: 'a-wanthirl'}) , (b:Subword {Yanyuwa: 'rra-'}),
# MERGE (a)-[r:Word_Subword_Relation]->(b);
