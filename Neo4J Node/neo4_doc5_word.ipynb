# %% [raw]
# ## Duwarra wujara Book
#
# #### P1
# 1: Kawula-arri wulwiyila arrkula malbu kawulilu-kunkunma barra, ka-arri walkurr.
#
# 2: Kawula-arri windajkumba warrinykumba.
#
# 3: Dambulyama ka-arri barra, “Aaah jina wardi awara marruwarra ngarna windajku, warringku barra. Kawa ngathangka ngali barra kali-wingkala ankaya alanjilu kukurdilu”.
#
# 4: Mawurrinya kilu-ngarninyma, “Yuwu marruwarra yabi barra wuka yinku barra, ngali barra ankaya alanjilu”.
#
# 5: Kawula-wingka kulu kawula-wukanyi rriya-wulanga rriyiwukuku.
#
# 6: Dambulyama ka-arri anku “Kukurdi mbila-kaya ngatharralu ma-rnayi kulu wabuda warrinyku katharrambamirra!”
#
# #### P2
# 1: Kawula-wukanyi wulanga rriya-wulanga rriyi-wukukuwujara, “Kurdardi! Kurdardi! Baku! Baku! Mbila-yukumaya alunga li-malbumalbu, kalu-wajimbangundarra yimbalanga!”
#
# 2: Kulu rrarrku kanda-arri, “Baku! Baku! Waniya! Waniya waykaliya! Ma-rnayi kimbala-rarrmala baku barni-kimbalangatharra ngundarru mbilayukumaya alunga. Baku! Baku! Mbila-nmaya nganambaji barra narnu-yuwa”.

# %%
MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'arrkula'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'malbu'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'barra'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);
MATCH (a:Sentence {Sequence_number: 3, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'barra'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);
MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'barra'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);
MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 2,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'barra'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

MATCH (a:Sentence {Sequence_number: 3, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'jina'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

MATCH (a:Sentence {Sequence_number: 3, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'awara'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

MATCH (a:Sentence {Sequence_number: 3, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'kurdardi'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 2,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'waykaliya'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

# %%
CREATE (:Word
    {
    Yanyuwa: 'walkurr',
    POS:'adverb ',
    In_English: 'Asleep.',
    Antonym: '',
    Synonym: '',
    Hypernymy: '',
    Hyponymy: '',
    Root: '',
    Stem: ''
    }
);
MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'walkurr'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

CREATE (:Word
    {
    Yanyuwa: 'dambulyama',
    POS:'noun  ',
    In_English: 'Name for a man of the Rrumburriya clan. The name belongs to the Hill Kangaroo Dreaming. This name comes from the country of Burrulula (Borroloola).',
    Antonym: '',
    Synonym: '',
    Hypernymy: '',
    Hyponymy: '',
    Root: '',
    Stem: ''
    }
);
MATCH (a:Sentence {Sequence_number: 3, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'dambulyama'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);
MATCH (a:Sentence {Sequence_number: 6, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'dambulyama'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

CREATE (:Word
    {
    Yanyuwa: 'wardi',
    POS:'adjective',
    In_English: '1) bad; 2) naughty; 3) foolish; 4) wrongful actions or behaviour.',
    Antonym: '',
    Synonym: '',
    Hypernymy: '',
    Hyponymy: '',
    Root: '',
    Stem: ''
    }
);
MATCH (a:Sentence {Sequence_number: 3, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'wardi'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

CREATE (:Word
    {
    Yanyuwa: 'marruwarra',
    POS:'noun ',
    In_English: ' Family: 1) my mother’s brother’s children; 2) my father’s sister’s children.',
    Antonym: '',
    Synonym: '',
    Hypernymy: '',
    Hyponymy: '',
    Root: '',
    Stem: ''
    }
);
MATCH (a:Sentence {Sequence_number: 3, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'marruwarra'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);
MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'marruwarra'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

CREATE (:Word
    {
    Yanyuwa: 'ngarna',
    POS:'pronoun ',
    In_English: ' 1) I; 2) me.',
    Antonym: '',
    Synonym: '',
    Hypernymy: '',
    Hyponymy: '',
    Root: '',
    Stem: ''
    }
);
MATCH (a:Sentence {Sequence_number: 3, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'ngarna'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

CREATE (:Word
    {
    Yanyuwa: 'warringku',
    POS:'adverb ',
    In_English: 'Thirsty.',
    Antonym: '',
    Synonym: '',
    Hypernymy: '',
    Hyponymy: '',
    Root: '',
    Stem: ''
    }
);
MATCH (a:Sentence {Sequence_number: 3, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'warringku'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

CREATE (:Word
    {
    Yanyuwa: 'ngali',
    POS:'pronoun ',
    In_English: 'The two of us.',
    Antonym: '',
    Synonym: '',
    Hypernymy: '',
    Hyponymy: '',
    Root: '',
    Stem: ''
    }
);
MATCH (a:Sentence {Sequence_number: 3, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'ngali'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);
MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'ngali'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

CREATE (:Word
    {
    Yanyuwa: 'yuwu',
    POS:'adverb ',
    In_English: 'Yes.',
    Antonym: '',
    Synonym: '',
    Hypernymy: '',
    Hyponymy: '',
    Root: '',
    Stem: ''
    }
);
MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'yuwu'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);


CREATE (:Word
    {
    Yanyuwa: 'yabi',
    POS:'adjective ',
    In_English: ' 1) good; 2) nice; 3) pleasant; 4) sweet; 5) happy.',
    Antonym: '',
    Synonym: '',
    Hypernymy: '',
    Hyponymy: '',
    Root: '',
    Stem: ''
    }
);
MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'yabi'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

CREATE (:Word
    {
    Yanyuwa: 'wuka',
    POS:'noun ',
    In_English: ' 1) word; 2) language; 3) story; 4) speech.',
    Antonym: '',
    Synonym: '',
    Hypernymy: '',
    Hyponymy: '',
    Root: '',
    Stem: ''
    }
);
MATCH (a:Sentence {Sequence_number: 5, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'wuka'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);
MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'wuka'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);
MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'wuka'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

CREATE (:Word
    {
    Yanyuwa: 'yinku',
    POS:'pronoun ',
    In_English: '1) for you (singular); 2) yours (singular).',
    Antonym: '',
    Synonym: '',
    Hypernymy: '',
    Hyponymy: '',
    Root: '',
    Stem: ''
    }
);
MATCH (a:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'yinku'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

CREATE (:Word
    {
    Yanyuwa: 'anku',
    POS:'pronoun ',
    In_English: ' Hers. There is no hyphen when a prefix is attached.',
    Antonym: '',
    Synonym: '',
    Hypernymy: '',
    Hyponymy: '',
    Root: '',
    Stem: ''
    }
);
MATCH (a:Sentence {Sequence_number: 6, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'anku'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

CREATE (:Word
    {
    Yanyuwa: 'ma-rnayi',
    POS:'noun ',
    In_English: 'Water lily corms (generic).',
    Antonym: '',
    Synonym: '',
    Hypernymy: '',
    Hyponymy: '',
    Root: '',
    Stem: ''
    }
);
MATCH (a:Sentence {Sequence_number: 6, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'ma-rnayi'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);
MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 2,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'ma-rnayi'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

CREATE (:Word
    {
    Yanyuwa: 'wulanga',
    POS:'noun ',
    In_English: ' For those two people.',
    Antonym: '',
    Synonym: '',
    Hypernymy: '',
    Hyponymy: '',
    Root: '',
    Stem: ''
    }
);
MATCH (a:Sentence {Sequence_number: 5, Source_Paragraph: 1,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'wulanga'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);
MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'wulanga'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

CREATE (:Word
    {
    Yanyuwa: 'baku',
    POS:'adverb ',
    In_English: '1) later today; 2) later. Used when you know that you will be meeting the person again later in the day.',
    Antonym: '',
    Synonym: '',
    Hypernymy: '',
    Hyponymy: '',
    Root: '',
    Stem: ''
    }
);
MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'baku'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);
MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 2,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'baku'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

CREATE (:Word
    {
    Yanyuwa: 'alunga',
    POS:'pronoun ',
    In_English: '1) for those people; 2) for them (people); 3) their.',
    Antonym: '',
    Synonym: '',
    Hypernymy: '',
    Hyponymy: '',
    Root: '',
    Stem: ''
    }
);
MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'alunga'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);
MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 2,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'alunga'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

CREATE (:Word
    {
    Yanyuwa: 'yimbalanga',
    POS:'pronoun ',
    In_English: 'For you two.',
    Antonym: '',
    Synonym: '',
    Hypernymy: '',
    Hyponymy: '',
    Root: '',
    Stem: ''
    }
);
MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'yimbalanga'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

CREATE (:Word
    {
    Yanyuwa: 'rrarrku',
    POS:'pronoun ',
    In_English: '(m&w) That other female/feminine one.',
    Antonym: '',
    Synonym: '',
    Hypernymy: '',
    Hyponymy: '',
    Root: '',
    Stem: ''
    }
);
MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 2,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'rrarrku'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

CREATE (:Word
    {
    Yanyuwa: 'narnu-yuwa',
    POS:'noun ',
    In_English: '1) the Law; 2) the reason why; 3) the answer; 4) culture; 5) tradition.',
    Antonym: '',
    Synonym: '',
    Hypernymy: '',
    Hyponymy: '',
    Root: '',
    Stem: ''
    }
);
MATCH (a:Sentence {Sequence_number: 2, Source_Paragraph: 2,  Source: 'Duwarra wujara Book'}) , (b:Word {Yanyuwa: 'narnu-yuwa'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);

# %%
CREATE (:Subword
    {
    Yanyuwa: 'nya-',
    Type: 'Prefix',
    Root: '',
    Usage: ''
    }
);

MATCH (a:Word {Yanyuwa: 'dambulyama'}) , (b:Subword {Yanyuwa: 'nya-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
MATCH (a:Word {Yanyuwa: 'wardi'}) , (b:Subword {Yanyuwa: 'cm-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
MATCH (a:Word {Yanyuwa: 'yabi'}) , (b:Subword {Yanyuwa: 'cm-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
MATCH (a:Word {Yanyuwa: 'anku'}) , (b:Subword {Yanyuwa: 'cm-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
MATCH (a:Word {Yanyuwa: 'wulanga'}) , (b:Subword {Yanyuwa: 'cm-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
MATCH (a:Word {Yanyuwa: 'alunga'}) , (b:Subword {Yanyuwa: 'cm-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
MATCH (a:Word {Yanyuwa: 'yimbalanga'}) , (b:Subword {Yanyuwa: 'cm-'}), 
MERGE (a)-[r:Word_Subword_Relation]->(b);
