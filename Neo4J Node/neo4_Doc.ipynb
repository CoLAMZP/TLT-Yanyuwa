# %% [markdown]
# ## Corpus

# %%
### Corpus

CREATE (:Corpus
    {
    Title: 'The Country of Yanyuwa Language',
    Source: 'A Yanyuwa Encyclopaedia Volume 1',
    Contributors: 'Yanyuwa Families and John Bradley, incorporating the work of Jean Kirton and Elfreda MacDonald'
    }
);

CREATE (:Corpus
    {
    Title: 'Recording Yanyuwa: People, Words and Meanings',
    Source: 'A Yanyuwa Encyclopaedia Volume 1',
    Contributors: 'Yanyuwa Families and John Bradley, incorporating the work of Jean Kirton and Elfreda MacDonald'
    }
);

CREATE (:Corpus
    {
    Title: 'Yanyuwa Texts',
    Source: 'A Yanyuwa Encyclopaedia Volume 1',
    Contributors: 'Yanyuwa Families and John Bradley, incorporating the work of Jean Kirton and Elfreda MacDonald'
    }
);

CREATE (:Corpus
    {
    Title: 'Yanyuwa Song Poetry',
    Source: 'A Yanyuwa Encyclopaedia Volume 1',
    Contributors: 'Yanyuwa Families and John Bradley, incorporating the work of Jean Kirton and Elfreda MacDonald'
    }
);

CREATE (:Corpus
    {
    Title: 'Ancestral Dreaming Texts',
    Source: 'A Yanyuwa Encyclopaedia Volume 1',
    Contributors: 'Yanyuwa Families and John Bradley, incorporating the work of Jean Kirton and Elfreda MacDonald'
    }
);

CREATE (:Corpus
    {
    Title: 'Duwarra wujara Book',
    Source: 'Duwarra wujara Book',
    Contributors: 'YANYUWA FAMILIES'
    }
);

CREATE (:Corpus
    {
    Title: 'Gulf Country Song Book',
    Source: 'Gulf Country Song Book',
    Contributors: 'COMPOSED BY SENIOR YANYUWA MEN AND WOMEN ON AND FOR THEIR COUNTRY'
    }
);

# %% [markdown]
# ## Document

# %%
### Document

CREATE (:Document
    {
    Title: 'Languages before non-Aboriginal contact',
    Year: '',
    Source: 'The Country of Yanyuwa Language',
    Contributors: '',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'The contemporary language community',
    Year: '',
    Source: 'The Country of Yanyuwa Language',
    Contributors: '',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Initial non-Aboriginal contact',
    Year: '',
    Source: 'The Country of Yanyuwa Language',
    Contributors: '',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Borroloola and the Malarndarri camp',
    Year: '',
    Source: 'The Country of Yanyuwa Language',
    Contributors: '',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'The cattle industry',
    Year: '',
    Source: 'The Country of Yanyuwa Language',
    Contributors: '',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Education: schools and policy',
    Year: '',
    Source: 'The Country of Yanyuwa Language',
    Contributors: '',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Recent trends',
    Year: '',
    Source: 'The Country of Yanyuwa Language',
    Contributors: '',
    English_translation: '',
    Location: ''
    }
);

# %%
### Document

CREATE (:Document
    {
    Title: 'Ludwig Leichhardt',
    Year: '',
    Source: 'Recording Yanyuwa: People, Words and Meanings',
    Contributors: '',
    English_translation: '',
    Location: ''
    }
);


CREATE (:Document
    {
    Title: 'W.G. Stretton',
    Year: '',
    Source: 'Recording Yanyuwa: People, Words and Meanings',
    Contributors: '',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Baldwin Spencer and Frank Gillen',
    Year: '',
    Source: 'Recording Yanyuwa: People, Words and Meanings',
    Contributors: '',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Arthur Capell ',
    Year: '',
    Source: 'Recording Yanyuwa: People, Words and Meanings',
    Contributors: '',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Marie Reay',
    Year: '',
    Source: 'Recording Yanyuwa: People, Words and Meanings',
    Contributors: '',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Ken Hale',
    Year: '',
    Source: 'Recording Yanyuwa: People, Words and Meanings',
    Contributors: '',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Elwin Flint',
    Year: '',
    Source: 'Recording Yanyuwa: People, Words and Meanings',
    Contributors: '',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Jean Kirton, Elfreda MacDonald and Yasuko Nagai',
    Year: '',
    Source: 'Recording Yanyuwa: People, Words and Meanings',
    Contributors: '',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'John Bradley',
    Year: '',
    Source: 'Recording Yanyuwa: People, Words and Meanings',
    Contributors: '',
    English_translation: '',
    Location: ''
    }
);

# %%
### Document

CREATE (:Document
    {
    Title: 'Old Man Monday and the Publican',
    Year: '1959–62',
    Source: 'Yanyuwa Texts',
    Contributors: 'Pharaoh Lhawulhawu, Marie Reay',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'The Story of Tommy Dodd',
    Year: '1959–62',
    Source: 'Yanyuwa Texts',
    Contributors: 'Pharaoh Lhawulhawu, Marie Reay',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Spirit Man Dreaming',
    Year: '1959',
    Source: 'Yanyuwa Texts',
    Contributors: 'Pharaoh Lhawulhawu, Ken Hale',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Kangaroo Dreaming',
    Year: '1959',
    Source: 'Yanyuwa Texts',
    Contributors: 'Pharaoh Lhawulhawu, Ken Hale',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Two Short Texts in Respectful Language',
    Year: '1959',
    Source: 'Yanyuwa Texts',
    Contributors: 'Pharaoh Lhawulhawu, Ken Hale',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Eating the Woman',
    Year: '1964–84',
    Source: 'Yanyuwa Texts',
    Contributors: 'Arthur Narnungawurruwurru, Jean Kirton',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'The Rainbow Serpent',
    Year: '1964–84',
    Source: 'Yanyuwa Texts',
    Contributors: 'Pluto Wurrumungkumungku, Jean Kirton',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Gathering for Fighting',
    Year: '1964–84',
    Source: 'Yanyuwa Texts',
    Contributors: 'Pluto Wurrumungkumungku, Jean Kirton',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'The American Airmen',
    Year: '1964–84',
    Source: 'Yanyuwa Texts',
    Contributors: 'Pluto Wurrumungkumungku, Jean Kirton',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Murder on Vanderlin Island',
    Year: '1964–84',
    Source: 'Yanyuwa Texts',
    Contributors: 'Arthur Narnungawurruwurru, Jean Kirton',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'The Coming of the White Man',
    Year: '1964–84',
    Source: 'Yanyuwa Texts',
    Contributors: 'Pharaoh Lhawulhawu, Jean Kirton',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Pubic Coverings and Hair String',
    Year: '1980–81 ',
    Source: 'Yanyuwa Texts',
    Contributors: 'Annie Isaac a-Karrakany, Yasuko Nagai',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'When Thelma Douglas Broke Her Leg',
    Year: '1980–81 ',
    Source: 'Yanyuwa Texts',
    Contributors: 'Don Miller Manarra, Yasuko Nagai',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Hunting for Long-Necked Turtles',
    Year: '1980–81 ',
    Source: 'Yanyuwa Texts',
    Contributors: 'Dinah Norman a-Marrngawi, Yasuko Nagai',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'The Jabiru, the Black-Nosed Python and the Dingo',
    Year: '1980–81 ',
    Source: 'Yanyuwa Texts',
    Contributors: 'Bella Charlie a-Marrajabu, Yasuko Nagai',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Hong Kong Flu Epidemic at Malarndarri Camp, 1969',
    Year: '1969 ',
    Source: 'Yanyuwa Texts',
    Contributors: 'Eileen McDinny a-Manankurrmara, John Bradley',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'The Spirit and the Old Lady',
    Year: '1982–2013 ',
    Source: 'Yanyuwa Texts',
    Contributors: 'Eileen McDinny a-Manankurrmara, John Bradley',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Majarla and the Saltwater Crocodile Attack',
    Year: '1982–2013 ',
    Source: 'Yanyuwa Texts',
    Contributors: 'Dinah Norman a-Marrngawi, John Bradley',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'The Death of the Old Man and What Happened',
    Year: '1982–2013 ',
    Source: 'Yanyuwa Texts',
    Contributors: 'Eileen McDinny a-Manankurrmara, John Bradley',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Path of the Mambaliya-Wawukarriya Songlines’',
    Year: '1982–2013 ',
    Source: 'Yanyuwa Texts',
    Contributors: 'Dinny McDinny Nyilba, John Bradley',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'My Aunty Wambadurna Ran Away',
    Year: '1982–2013 ',
    Source: 'Yanyuwa Texts',
    Contributors: 'Bella Charlie a-Marrajabu, John Bradley',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'The Young People',
    Year: '1982–2013 ',
    Source: 'Yanyuwa Texts',
    Contributors: 'Pyro Dirdiyalma, John Bradley',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'The Giving of a Promised Wife',
    Year: '1982–2013 ',
    Source: 'Yanyuwa Texts',
    Contributors: 'Eileen McDinny a-Manankurrmara, John Bradley',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Concerning the Two Men Who Drowned',
    Year: '1982–2013 ',
    Source: 'Yanyuwa Texts',
    Contributors: 'Amy Friday a-Bajamalanya and Bella Charlie a-Marrajabu, John Bradley',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'The Death of Horace Foster at Manangoora',
    Year: '1982–2013 ',
    Source: 'Yanyuwa Texts',
    Contributors: 'Bessie Marshall a-Kithibula, John Bradley',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Journey East, 1988 (1)',
    Year: '1988',
    Source: 'Yanyuwa Texts',
    Contributors: 'Eileen McDinny a-Manankurrmara, John Bradley',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Journey East, 1988 (2)',
    Year: '1988',
    Source: 'Yanyuwa Texts',
    Contributors: 'Dinah Norman a-Marrngawi, John Bradley',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Journey East, 1988 (3)',
    Year: '1988',
    Source: 'Yanyuwa Texts',
    Contributors: 'Eileen McDinny a-Manankurrmara, John Bradley',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Murder on Vanderlin Island',
    Year: '1982–2013 ',
    Source: 'Yanyuwa Texts',
    Contributors: 'Ida Ninganga, John Bradley',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Searching for the American Airmen and Finding the Aeroplane Dance',
    Year: '1982–2013 ',
    Source: 'Yanyuwa Texts',
    Contributors: 'Ron Ricket Murundu, John Bradley',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Runaway Lovers and Their Punishment',
    Year: '1982–2013 ',
    Source: 'Yanyuwa Texts',
    Contributors: 'Eileen McDinny a-Manankurrmara, John Bradley',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'The Runaway Woman and the Revenge Party',
    Year: '1982–2013 ',
    Source: 'Yanyuwa Texts',
    Contributors: 'Old Tim Timothy Rakawurlma, John Bradley',
    English_translation: '',
    Location: ''
    }
);

# %%
CREATE (:Document
    {
    Title: 'Barracuda',
    Year: '',
    Source: 'Ancestral Dreaming Texts',
    Contributors: 'a-Mukarra',
    English_translation: '',
    Location: 'McArthur River and Kangaroo Island'
    }
);

CREATE (:Document
    {
    Title: 'Black-Nosed Python',
    Year: '',
    Source: 'Ancestral Dreaming Texts',
    Contributors: 'a-Buburna',
    English_translation: '',
    Location: 'Limmen Bight, Bing Bong and Carrington Channel'
    }
);


CREATE (:Document
    {
    Title: 'Chicken Hawk and the Crow',
    Year: '',
    Source: 'Ancestral Dreaming Texts',
    Contributors: 'Malarrkarrka kulu a-Wangka',
    English_translation: '',
    Location: 'Black Rocks and the plains country to the east'
    }
);

CREATE (:Document
    {
    Title: 'Dingo',
    Year: '',
    Source: 'Ancestral Dreaming Texts',
    Contributors: 'Wurrundurla',
    English_translation: '',
    Location: 'Fletcher Creek down to the mouth of the Crooked River'
    }
);

CREATE (:Document
    {
    Title: 'Dugong Hunters',
    Year: '',
    Source: 'Ancestral Dreaming Texts',
    Contributors: 'li-Maramaranja',
    English_translation: '',
    Location: 'Vanderlin Island, North Island, Skull Island, White and Black Craggy Islands, West Island, Rosie Creek mouth, Limmen Bight and Mount Young'
    }
);

CREATE (:Document
    {
    Title: 'Groper',
    Year: '',
    Source: 'Ancestral Dreaming Texts',
    Contributors: 'a-Kuridi',
    English_translation: '',
    Location: 'near old Doomadgee Mission, South West Island and Roper River'
    }
);

CREATE (:Document
    {
    Title: 'Hammerhead Shark',
    Year: '',
    Source: 'Ancestral Dreaming Texts',
    Contributors: 'Warriyangalayawu',
    English_translation: '',
    Location: 'north of the Roper River mouth, Vanderlin Rocks and Vanderlin Island'
    }
);

CREATE (:Document
    {
    Title: 'Hill Kangaroo',
    Year: '',
    Source: 'Ancestral Dreaming Texts',
    Contributors: 'Nangurrbuwala',
    English_translation: '',
    Location: 'Cape Crawford, Borroloola, Malarndarri Old Camp, Police Lagoon and the McArthur River Crossing'
    }
);

CREATE (:Document
    {
    Title: 'Rain and Rib Bones of the Rainbow Serpent',
    Year: '',
    Source: 'Ancestral Dreaming Texts',
    Contributors: 'Wabuda kulu na-lalurr ki-Bujimalawu',
    English_translation: '',
    Location: 'McPherson Creek and country to the west of Manangoora'
    }
);

CREATE (:Document
    {
    Title: 'The Rainbow Serpent Belonging to Walala and the Mouth of the Eagle Ray at Wulunthurr',
    Year: '',
    Source: 'Ancestral Dreaming Texts',
    Contributors: 'Bujimala jibiya Walala kulu Manumanu na-mulu jibiya Wulunthurr',
    English_translation: '',
    Location: 'Lake Eames and southern Vanderlin Island'
    }
);

CREATE (:Document
    {
    Title: 'Rock Cod',
    Year: '',
    Source: 'Ancestral Dreaming Texts',
    Contributors: 'Wangkuwa',
    English_translation: '',
    Location: 'Sharker Point'
    }
);

CREATE (:Document
    {
    Title: 'Saltwater Crocodile and Willy Wagtail',
    Year: '',
    Source: 'Ancestral Dreaming Texts',
    Contributors: 'Mardumbarra kulu a-Kijirrikijirri',
    English_translation: '',
    Location: 'Batten Creek'
    }
);

CREATE (:Document
    {
    Title: 'Sea Turtle and the Osprey',
    Year: '',
    Source: 'Ancestral Dreaming Texts',
    Contributors: 'Wundanyuka kulu Jujuju',
    English_translation: '',
    Location: 'Pine Creek, West Island, Watson Island and North Island'
    }
);

CREATE (:Document
    {
    Title: 'Spirit People',
    Year: '',
    Source: 'Ancestral Dreaming Texts',
    Contributors: 'Ngabaya',
    English_translation: '',
    Location: 'Frog Rock, Jump Up, Goose Lagoon, Foelsche River, Rocky, country to the southeast of the Fat Fellows Creek, Sandy Head and parts of the east coast of Vanderlin Island'
    }
);

CREATE (:Document
    {
    Title: 'Spotted Nightjar',
    Year: '',
    Source: 'Ancestral Dreaming Texts',
    Contributors: 'Yilayi',
    English_translation: '',
    Location: 'Black Rocks, King Ash Bay and Duck Island'
    }
);

CREATE (:Document
    {
    Title: 'Stone Dreaming',
    Year: '',
    Source: 'Ancestral Dreaming Texts',
    Contributors: 'a-Kuwaykuwayk',
    English_translation: '',
    Location: 'Calvert River, Robinson River, Vanderlin Island, Willy Islet and Centre Island'
    }
);

CREATE (:Document
    {
    Title: 'Tiger Shark',
    Year: '',
    Source: 'Ancestral Dreaming Texts',
    Contributors: 'Ngurdungurdu',
    English_translation: '',
    Location: 'near Doomadgee, Vanderlin Rocks, Vanderlin Island, Wearyan River and Manangoora'
    }
);

CREATE (:Document
    {
    Title: 'Two Initiates and the Rainbow Serpent',
    Year: '',
    Source: 'Ancestral Dreaming Texts',
    Contributors: 'Rduwarrawujara kulu Bujimala',
    English_translation: '',
    Location: 'Five Mile Bend, to Ngambingambi Rockhole, McArthur River to Centre Island, Horn Islet, Observation Island, Pearce Islet and Urquhart Island'
    }
);

CREATE (:Document
    {
    Title: 'Wedge-Tailed Eagle and Crow',
    Year: '',
    Source: 'Ancestral Dreaming Texts',
    Contributors: 'a-Kilyarrkilyarr kulu a-Wangka',
    English_translation: '',
    Location: 'Barkly Tablelands, top of the McArthur River, Robinson River and McPherson Creek'
    }
);

CREATE (:Document
    {
    Title: 'Whirlwind Rainbow Serpent',
    Year: '',
    Source: 'Ancestral Dreaming Texts',
    Contributors: 'Walalu',
    English_translation: '',
    Location: 'Massacre Inlet, Calvert River, Robinson River, Foelsche River, Wearyan River, Twenty Mile Flat, Poison Creek, Duck Island and Batten Creek'
    }
);

CREATE (:Document
    {
    Title: 'White-Bellied Sea Eagle',
    Year: '',
    Source: 'Ancestral Dreaming Texts',
    Contributors: 'a-Karnkarnka',
    English_translation: '',
    Location: 'east bank of the mouth of the Wearyan River, Cape Vanderlin, and Red Bluff on North Island'
    }
);

CREATE (:Document
    {
    Title: 'Women/Mermaids',
    Year: '',
    Source: 'Ancestral Dreaming Texts',
    Contributors: 'a-Mararabarna',
    English_translation: '',
    Location: 'mouth of the Rosie Creek, Pine Creek down on to Wahallow Station'
    }
);

# %%
CREATE (:Document
    {
    Title: 'Saltwater People People of the Sea',
    Year: '1992',
    Source: 'Gulf Country Song Book',
    Contributors: 'Composed by Dinah Norman a-Marrngawi, Eileen McDinny a-Manankurrmara, Annie a-Karrakayny; Sung by Dinah Norman a-Marrngawi, Jemima Miller a-Wuwarlu, Roddy Harvey a-Bayiwuma, Nancy McDinny aYukuwalamara and Marjorie Keighran Maningirri',
    English_translation: '',
    Location: ''
    }
);

CREATE (:Document
    {
    Title: 'Deaf to the sound of the conch shell',
    Year: '',
    Source: 'Gulf Country Song Book',
    Contributors: 'Composed by Peter Jangurringurri; Sung by Eileen McDinny a-Manankurrmara',
    English_translation: '',
    Location: ''
    }
);


CREATE (:Document
    {
    Title: 'Terns at Yinijini',
    Year: '',
    Source: 'Gulf Country Song Book',
    Contributors: 'Song composed by Judy Timothy a-Marrngawi and Maggie a-Bukundumara; Sung by Eileen McDinny a-Manankurrmara',
    English_translation: '',
    Location: 'Yinijini'
    }
);


CREATE (:Document
    {
    Title: 'Gathering Trepang at Karruwa (Little Vanderlin Island)',
    Year: '',
    Source: 'Gulf Country Song Book',
    Contributors: 'Composed by Jack Baju; Sung by Nora a-Jalirduma',
    English_translation: '',
    Location: 'Little Vanderlin Island'
    }
);


CREATE (:Document
    {
    Title: 'Which way now? And the High Hill Wirdijila',
    Year: '',
    Source: 'Gulf Country Song Book',
    Contributors: 'Composed by Short Friday Babawurda; Sung by Eileen McDinny a-Manankurrmara',
    English_translation: '',
    Location: ''
    }
);

# %% [markdown]
# ## Incident at Rruwangkala [Black Rocks]

# %% [raw]
# CREATE (:Document
#     {
#     Title: 'Incident at Rruwangkala [Black Rocks]',
#     Year: '1959–62',
#     Source: 'Yanyuwa Texts',
#     Contributors: 'Pharaoh Lhawulhawu, Marie Reay',
#     English_translation: 'It was down at Rruwangkala [Black Rocks] a long time ago; it has nothing to do with these times. They [Yanyuwa people] were stealing food [from white people]. They were swimming across the river and they got tea, and they also got a gun, blankets and some calico. Their camp was in the west, in the middle of the bush, on the west bank. One young man, he got the gun and carried it with the gunstock resting on his head; he swam carrying the gun. The gun was a doublebarrelled shotgun; it had two bullets inside. They were all cooking the flour. He showed them the gun and said, ‘It is with this one that white people have been shooting us before and while here. It is another kind of thing, this one.’ He held the gun as if to shoot. Again he showed them the gun. He pointed the barrels at them and he pulled the trigger. The bullets exploded; he had shot them, he shot children, women and men. He threw the gun away and ran away; he ran away and he stayed away forever, the poor fellow.',
#     Location: ''
#     }
# );
#
# MATCH (a:Document {Title: 'Incident at Rruwangkala [Black Rocks]'}), (b:Paragraph {Sequence_number: 1, Source: 'Incident at Rruwangkala [Black Rocks]'})
# MERGE (a)-[r:Document_Paragraph_Relation]->(b);
#
# MATCH (a:Document {Title: 'Incident at Rruwangkala [Black Rocks]'}), (b:Paragraph {Sequence_number: 2, Source: 'Incident at Rruwangkala [Black Rocks]'})
# MERGE (a)-[r:Document_Paragraph_Relation]->(b);
#
# MATCH (a:Document {Title: 'Incident at Rruwangkala [Black Rocks]'}), (b:Paragraph {Sequence_number: 3, Source: 'Incident at Rruwangkala [Black Rocks]'})
# MERGE (a)-[r:Document_Paragraph_Relation]->(b);
#
# MATCH (a:Document {Title: 'Incident at Rruwangkala [Black Rocks]'}), (b:Paragraph {Sequence_number: 4, Source: 'Incident at Rruwangkala [Black Rocks]'})
# MERGE (a)-[r:Document_Paragraph_Relation]->(b);
#
# MATCH (a:Document {Title: 'Incident at Rruwangkala [Black Rocks]'}), (b:Paragraph {Sequence_number: 5, Source: 'Incident at Rruwangkala [Black Rocks]'})
# MERGE (a)-[r:Document_Paragraph_Relation]->(b);
#
#
# CREATE (:Paragraph
#     {
#     Sequence_number: 1,
#     English_translation: 'It was down at Rruwangkala [Black Rocks] a long time ago; it has nothing to do with these times. They [Yanyuwa people] were stealing food [from white people]. They were swimming across the river and they got tea, and they also got a gun, blankets and some calico.',
#     English_explanation: '',
#     Source: 'Incident at Rruwangkala [Black Rocks]'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 1,
#     Source_Paragraph: 1,
#     English_translation: 'Down Rruwangkala long time ago olden times nothing in the middle.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source: 'Incident at Rruwangkala [Black Rocks]'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 2,
#     Source_Paragraph: 1,
#     English_translation: 'They were stealing food and they were swimming.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source: 'Incident at Rruwangkala [Black Rocks]'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 3,
#     Source_Paragraph: 1,
#     English_translation: 'They got tea also they got it gun blanket calico they were getting.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source: 'Incident at Rruwangkala [Black Rocks]'
#     }
# );
#
#
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Sentence {Sequence_number: 1, Source_Paragraph: 1, Source: 'Incident at Rruwangkala [Black Rocks]'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
#
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Sentence {Sequence_number: 2, Source_Paragraph: 1, Source: 'Incident at Rruwangkala [Black Rocks]'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
#
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Sentence {Sequence_number: 3, Source_Paragraph: 1, Source: 'Incident at Rruwangkala [Black Rocks]'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
#
#
# CREATE (:Paragraph
#     {
#     Sequence_number: 2,
#     English_translation: 'Their camp was in the west, in the middle of the bush, on the west bank. One young man, he got the gun and carried it with the gunstock resting on his head; he swam carrying the gun. The gun was a doublebarrelled shotgun; it had two bullets inside.',
#     English_explanation: '',
#     Source: 'Incident at Rruwangkala [Black Rocks]'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 1,
#     Source_Paragraph: 2,
#     English_translation: 'To the west in the middle on the west side camp one young man he got gun it’s wood.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source: 'Incident at Rruwangkala [Black Rocks]'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 2,
#     Source_Paragraph: 2,
#     English_translation: 'In this way on the head with him he swam carrying it.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source: 'Incident at Rruwangkala [Black Rocks]'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 3,
#     Source_Paragraph: 2,
#     English_translation: 'Two mouth two it had two eyes inside.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source: 'Incident at Rruwangkala [Black Rocks]'
#     }
# );
#
#
# MATCH (a:Paragraph {Sequence_number: 2, Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Sentence {Sequence_number: 1, Source_Paragraph: 2, Source: 'Incident at Rruwangkala [Black Rocks]'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
#
# MATCH (a:Paragraph {Sequence_number: 2, Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Sentence {Sequence_number: 2, Source_Paragraph: 2, Source: 'Incident at Rruwangkala [Black Rocks]'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
#
# MATCH (a:Paragraph {Sequence_number: 2, Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Sentence {Sequence_number: 3, Source_Paragraph: 2, Source: 'Incident at Rruwangkala [Black Rocks]'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
#
#
#
# CREATE (:Paragraph
#     {
#     Sequence_number: 3,
#     English_translation: 'They were all cooking the flour.',
#     English_explanation: '',
#     Source: 'Incident at Rruwangkala [Black Rocks]'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 1,
#     Source_Paragraph: 3,
#     English_translation: 'They cooked flour, they were all cooking it.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source: 'Incident at Rruwangkala [Black Rocks]'
#     }
# );
#
# MATCH (a:Paragraph {Sequence_number: 3, Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Sentence {Sequence_number: 1, Source_Paragraph: 3, Source: 'Incident at Rruwangkala [Black Rocks]'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
#
#
# CREATE (:Paragraph
#     {
#     Sequence_number: 4,
#     English_translation: 'He showed them the gun and said, ‘It is with this one that white people have been shooting us before and while here. It is another kind of thing, this one.’ He held the gun as if to shoot.',
#     English_explanation: '',
#     Source: 'Incident at Rruwangkala [Black Rocks]'
#     }
# );
#
#
# CREATE (:Sentence
#     {
#     Sequence_number: 1,
#     Source_Paragraph: 4,
#     English_translation: 'Gun he showed them with this one now before white people they are shooting while here another kind this one he carried this way.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source: 'Incident at Rruwangkala [Black Rocks]'
#     }
# );
#
# MATCH (a:Paragraph {Sequence_number: 4, Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Sentence {Sequence_number: 1, Source_Paragraph: 4, Source: 'Incident at Rruwangkala [Black Rocks]'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
#
#
#
# CREATE (:Paragraph
#     {
#     Sequence_number: 5,
#     English_translation: 'Again he showed them the gun. He pointed the barrels at them and he pulled the trigger. The bullets exploded; he had shot them, he shot children, women and men. He threw the gun away and ran away; he ran away and he stayed away forever, the poor fellow.',
#     English_explanation: '',
#     Source: 'Incident at Rruwangkala [Black Rocks]'
#     }
# );
#
#
# CREATE (:Sentence
#     {
#     Sequence_number: 1,
#     Source_Paragraph: 5,
#     English_translation: 'Again straight he showed its mouth to them he dragged trigger it exploded he shot them finish shooting children women men he threw it gun he ran away he stayed away finish finish he stayed away he ran away the poor fellow he stayed away.
# ',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source: 'Incident at Rruwangkala [Black Rocks]'
#     }
# );
#
# MATCH (a:Paragraph {Sequence_number: 5, Source: 'Incident at Rruwangkala [Black Rocks]'}) , (b:Sentence {Sequence_number: 1, Source_Paragraph: 5, Source: 'Incident at Rruwangkala [Black Rocks]'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);

# %% [markdown]
# ## The Saltwater Crocodile and the Willy Wagtail

# %% [raw]
# CREATE (:Document
#     {
#     Title: 'The Saltwater Crocodile and the Willy Wagtail',
#     Year: '1959',
#     Source: 'Yanyuwa Texts',
#     Contributors: 'Pharaoh Lhawulhawu, Ken Hale',
#     English_translation: '',
#     Location: ''
#     }
# );
#
# CREATE (:Paragraph
#     {
#     Sequence_number: 1,
#     English_translation: 'The Saltwater Crocodile, he came to Nguwangkila [on the Batten Creek], and the Willy Wagtail was angry, she was furious.',
#     English_explanation: '',
#     Source: 'The Saltwater Crocodile and the Willy Wagtail'
#     }
# );
#
# CREATE (:Paragraph
#     {
#     Sequence_number: 2,
#     English_translation: 'She spoke to him, ‘Hey there! Down! Down! You sneaking one!’ She threw a pandanus palm downwards [at him].',
#     English_explanation: '',
#     Source: 'The Saltwater Crocodile and the Willy Wagtail'
#     }
# );
#
# CREATE (:Paragraph
#     {
#     Sequence_number: 3,
#     English_translation: 'She said to him, ‘You should eat kangaroos and wallabies, all different kinds of things. You should eat men, dogs, dingoes, all kinds of things. You should eat them, you intend to, you dangerous one, you Saltwater Crocodile who desires to bite.’ This is what she said to him, the Willy Wagtail to the Saltwater Crocodile.',
#     English_explanation: '',
#     Source: 'The Saltwater Crocodile and the Willy Wagtail'
#     }
# );
#
# CREATE (:Paragraph
#     {
#     Sequence_number: 4,
#     English_translation: 'And he is here now, eating us, he is eating all kinds of things, the saltwater crocodile; he eats dogs, bullocks, horses and also men.',
#     English_explanation: '',
#     Source: 'The Saltwater Crocodile and the Willy Wagtail'
#     }
# );
#
# CREATE (:Paragraph
#     {
#     Sequence_number: 5,
#     English_translation: 'In past times, the Saltwater Crocodile used to be eating people all the time, and he is here now and we are all frightened of the saltwater crocodile.',
#     English_explanation: '',
#     Source: 'The Saltwater Crocodile and the Willy Wagtail'
#     }
# );
#
# CREATE (:Paragraph
#     {
#     Sequence_number: 6,
#     English_translation: 'We no longer swim to the east side [of the river]; now we are paddling dugout canoes, we only go by dugout canoe.',
#     English_explanation: '',
#     Source: 'The Saltwater Crocodile and the Willy Wagtail'
#     }
# );
#
#
# CREATE (:Paragraph
#     {
#     Sequence_number: 7,
#     English_translation: 'That saltwater crocodile, he is one who has no fear, he is one who desires to bite; the saltwater crocodile is dangerous.',
#     English_explanation: '',
#     Source: 'The Saltwater Crocodile and the Willy Wagtail'
#     }
# );
#
#
# CREATE (:Paragraph
#     {
#     Sequence_number: 8,
#     English_translation: 'He is laying eggs and the saltwater crocodile has a great many babies.
# He is there now, the one who desires to bite, he who is the saltwater
# crocodile. Finished now.',
#     English_explanation: '',
#     Source: 'The Saltwater Crocodile and the Willy Wagtail'
#     }
# );
#
#
# MATCH (a:Document {Title: 'The Saltwater Crocodile and the Willy Wagtail'}), (b:Paragraph {Sequence_number: 1, Source: 'The Saltwater Crocodile and the Willy Wagtail'})
# MERGE (a)-[r:Document_Paragraph_Relation]->(b);
# MATCH (a:Document {Title: 'The Saltwater Crocodile and the Willy Wagtail'}), (b:Paragraph {Sequence_number: 2, Source: 'The Saltwater Crocodile and the Willy Wagtail'})
# MERGE (a)-[r:Document_Paragraph_Relation]->(b);
# MATCH (a:Document {Title: 'The Saltwater Crocodile and the Willy Wagtail'}), (b:Paragraph {Sequence_number: 3, Source: 'The Saltwater Crocodile and the Willy Wagtail'})
# MERGE (a)-[r:Document_Paragraph_Relation]->(b);
# MATCH (a:Document {Title: 'The Saltwater Crocodile and the Willy Wagtail'}), (b:Paragraph {Sequence_number: 4, Source: 'The Saltwater Crocodile and the Willy Wagtail'})
# MERGE (a)-[r:Document_Paragraph_Relation]->(b);
# MATCH (a:Document {Title: 'The Saltwater Crocodile and the Willy Wagtail'}), (b:Paragraph {Sequence_number: 5, Source: 'The Saltwater Crocodile and the Willy Wagtail'})
# MERGE (a)-[r:Document_Paragraph_Relation]->(b);
# MATCH (a:Document {Title: 'The Saltwater Crocodile and the Willy Wagtail'}), (b:Paragraph {Sequence_number: 6, Source: 'The Saltwater Crocodile and the Willy Wagtail'})
# MERGE (a)-[r:Document_Paragraph_Relation]->(b);
# MATCH (a:Document {Title: 'The Saltwater Crocodile and the Willy Wagtail'}), (b:Paragraph {Sequence_number: 7, Source: 'The Saltwater Crocodile and the Willy Wagtail'})
# MERGE (a)-[r:Document_Paragraph_Relation]->(b);
# MATCH (a:Document {Title: 'The Saltwater Crocodile and the Willy Wagtail'}), (b:Paragraph {Sequence_number: 8, Source: 'The Saltwater Crocodile and the Willy Wagtail'})
# MERGE (a)-[r:Document_Paragraph_Relation]->(b);
#
#
# CREATE (:Sentence
#     {
#     Sequence_number: 1,
#     Source_Paragraph: 1,
#     English_translation: 'Saltwater Crocodile he came.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source: 'The Saltwater Crocodile and the Willy Wagtail'
#     }
# );
#
#
# CREATE (:Sentence
#     {
#     Sequence_number: 2,
#     Source_Paragraph: 1,
#     English_translation: 'She was angry to the Willy Wagtail Nguwangkila she was angry.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source: 'The Saltwater Crocodile and the Willy Wagtail'
#     }
# );
#
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'The Saltwater Crocodile and the Willy Wagtail'}) , (b:Sentence {Sequence_number: 1, Source_Paragraph: 1, Source: 'The Saltwater Crocodile and the Willy Wagtail'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'The Saltwater Crocodile and the Willy Wagtail'}) , (b:Sentence {Sequence_number: 2, Source_Paragraph: 1, Source: 'The Saltwater Crocodile and the Willy Wagtail'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
#
#
# CREATE (:Sentence
#     {
#     Sequence_number: 1,
#     Source_Paragraph: 2,
#     English_translation: 'She spoke for him, ‘Hey there! Down! Down You should be sneaking one!’ Pandanus palm pandanus palm she threw downwards.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source: 'The Saltwater Crocodile and the Willy Wagtail'
#     }
# );
#
# MATCH (a:Paragraph {Sequence_number: 2, Source: 'The Saltwater Crocodile and the Willy Wagtail'}) , (b:Sentence {Sequence_number: 1, Source_Paragraph: 2, Source: 'The Saltwater Crocodile and the Willy Wagtail'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
#
#
#
# CREATE (:Sentence
#     {
#     Sequence_number: 1,
#     Source_Paragraph: 3,
#     English_translation: 'She said for him, ‘You should eat kangaroo/wallaby  all kinds of things men dog dingo all kinds of things you should eat you intend you dangerous one Saltwater Crocodile you who desire to bite’, she said for him, Willy Wagtail for the Saltwater Crocodile.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: ''
#     }
# );
#
# MATCH (a:Paragraph {Sequence_number: 3, Source: 'The Saltwater Crocodile and the Willy Wagtail'}) , (b:Sentence {Sequence_number: 1, Source_Paragraph: 3, Source: 'The Saltwater Crocodile and the Willy Wagtail'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
#
# CREATE (:Sentence
#     {
#     Sequence_number: 1,
#     Source_Paragraph: 4,
#     English_translation: 'And here he is now he is eating us, he is eating all kinds of things to the saltwater crocodile dog cattle horse also men.
# ',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: ''
#     }
# );
#
# MATCH (a:Paragraph {Sequence_number: 4, Source: 'The Saltwater Crocodile and the Willy Wagtail'}) , (b:Sentence {Sequence_number: 1, Source_Paragraph: 4, Source: 'The Saltwater Crocodile and the Willy Wagtail'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
#
#
# CREATE (:Sentence
#     {
#     Sequence_number: 1,
#     Source_Paragraph: 5,
#     English_translation: 'Past times he used to be eating them all the time to the Saltwater Crocodile and he is here now saltwater crocodile all of us are frightened for him or the saltwater crocodile.
# ',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: ''
#     }
# );
#
# MATCH (a:Paragraph {Sequence_number: 5, Source: 'The Saltwater Crocodile and the Willy Wagtail'}) , (b:Sentence {Sequence_number: 1, Source_Paragraph: 5, Source: 'The Saltwater Crocodile and the Willy Wagtail'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
#
# CREATE (:Sentence
#     {
#     Sequence_number: 1,
#     Source_Paragraph: 6,
#     English_translation: 'We no longer swim to the east side [of the river]; ',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: ''
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 2,
#     Source_Paragraph: 6,
#     English_translation: 'now we are paddling dugout canoes, we only go by dugout canoe.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: ''
#     }
# );
#
# MATCH (a:Paragraph {Sequence_number: 6, Source: 'The Saltwater Crocodile and the Willy Wagtail'}) , (b:Sentence {Sequence_number: 1, Source_Paragraph: 6, Source: 'The Saltwater Crocodile and the Willy Wagtail'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
# MATCH (a:Paragraph {Sequence_number: 6, Source: 'The Saltwater Crocodile and the Willy Wagtail'}) , (b:Sentence {Sequence_number: 2, Source_Paragraph: 6, Source: 'The Saltwater Crocodile and the Willy Wagtail'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
#
# CREATE (:Sentence
#     {
#     Sequence_number: 1,
#     Source_Paragraph: 7,
#     English_translation: 'That saltwater crocodile, he is one who has no fear, he is one who desires to bite; the saltwater crocodile is dangerous.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: ''
#     }
# );
#
# MATCH (a:Paragraph {Sequence_number: 7, Source: 'The Saltwater Crocodile and the Willy Wagtail'}) , (b:Sentence {Sequence_number: 1, Source_Paragraph: 7, Source: 'The Saltwater Crocodile and the Willy Wagtail'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
#
# CREATE (:Sentence
#     {
#     Sequence_number: 1,
#     Source_Paragraph: 8,
#     English_translation: 'He is laying eggs and the saltwater crocodile has a great many babies.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: ''
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 2,
#     Source_Paragraph: 8,
#     English_translation: 'He is there now, the one who desires to bite, he who is the saltwater crocodile. Finished now.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: ''
#     }
# );
#
# MATCH (a:Paragraph {Sequence_number: 8, Source: 'The Saltwater Crocodile and the Willy Wagtail'}) , (b:Sentence {Sequence_number: 1, Source_Paragraph: 8, Source: 'The Saltwater Crocodile and the Willy Wagtail'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
# MATCH (a:Paragraph {Sequence_number: 8, Source: 'The Saltwater Crocodile and the Willy Wagtail'}) , (b:Sentence {Sequence_number: 2, Source_Paragraph: 8, Source: 'The Saltwater Crocodile and the Willy Wagtail'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);

# %% [markdown]
# ## Burying the Dead

# %% [raw]
# CREATE (:Document
#     {
#     Title: 'Burying the Dead',
#     Year: '1964–84',
#     Source: 'Yanyuwa Texts',
#     Contributors: 'Arthur Narnungawurruwurru, Jean Kirton',
#     English_translation: '',
#     Location: ''
#     }
# );
#
# CREATE (:Paragraph
#     {
#     Sequence_number: 1,
#     English_translation: 'A long time before the white people, when a senior man died we did not bury him in the ground but would hang him up [put him up on a burial platform]. They would place them hanging up [place them up on a platform]. We would say, ‘We should hang him upwards [put him up on a platform]’.',
#     English_explanation: '',
#     Source: 'Burying the Dead'
#     }
# );
#
# CREATE (:Paragraph
#     {
#     Sequence_number: 2,
#     English_translation: 'The flesh would come off, they would pick up all the bones and place them in a bundle, and they would carry it. Others would be waiting there, they waited down there, all of them crying in that direction for the bones.',
#     English_explanation: '',
#     Source: 'Burying the Dead'
#     }
# );
#
# CREATE (:Paragraph
#     {
#     Sequence_number: 3,
#     English_translation: 'That old man spoke, ‘That log coffin, it will be standing in his country’.',
#     English_explanation: '',
#     Source: 'Burying the Dead'
#     }
# );
#
# CREATE (:Paragraph
#     {
#     Sequence_number: 4,
#     English_translation: '‘You will return his bones to his nephew, and he will place them. He will return his bones back to his country, so they remain there continually. Let him warm himself there.’',
#     English_explanation: '',
#     Source: 'Burying the Dead'
#     }
# );
#
# MATCH (a:Document {Title: 'Burying the Dead'}), (b:Paragraph {Sequence_number: 1, Source: 'Burying the Dead'})
# MERGE (a)-[r:Document_Paragraph_Relation]->(b);
# MATCH (a:Document {Title: 'Burying the Dead'}), (b:Paragraph {Sequence_number: 2, Source: 'Burying the Dead'})
# MERGE (a)-[r:Document_Paragraph_Relation]->(b);
# MATCH (a:Document {Title: 'Burying the Dead'}), (b:Paragraph {Sequence_number: 3, Source: 'Burying the Dead'})
# MERGE (a)-[r:Document_Paragraph_Relation]->(b);
# MATCH (a:Document {Title: 'Burying the Dead'}), (b:Paragraph {Sequence_number: 4, Source: 'Burying the Dead'})
# MERGE (a)-[r:Document_Paragraph_Relation]->(b);
#
#
# CREATE (:Sentence
#     {
#     Sequence_number: 1,
#     Source_Paragraph: 1,
#     English_translation: 'A long time before the white people, when a senior man died we did not bury him in the ground but would hang him up [put him up on a burial platform]. They would place them hanging up [place them up on a platform].',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Burying the Dead'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 2,
#     Source_Paragraph: 1,
#     English_translation: 'We would say, ‘We should hang him upwards [put him up on a platform]’.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Burying the Dead'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 1,
#     Source_Paragraph: 2,
#     English_translation: 'The flesh would come off, they would pick up all the bones and place them in a bundle, and they would carry it. Others would be waiting there, they waited down there, all of them crying in that direction for the bones.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Burying the Dead'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 1,
#     Source_Paragraph: 3,
#     English_translation: 'That old man spoke, ‘That log coffin, it will be standing in his country’.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Burying the Dead'
#     }
# );
#
#
# CREATE (:Sentence
#     {
#     Sequence_number: 1,
#     Source_Paragraph: 4,
#     English_translation: '‘You will return his bones to his nephew, and he will place them. He will return his bones back to his country, so they remain there continually. Let him warm himself there.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Burying the Dead'
#     }
# );
#
#
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'Burying the Dead'}) , (b:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Burying the Dead'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'Burying the Dead'}) , (b:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Burying the Dead'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
# MATCH (a:Paragraph {Sequence_number: 2, Source: 'Burying the Dead'}) , (b:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Burying the Dead'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
# MATCH (a:Paragraph {Sequence_number: 3, Source: 'Burying the Dead'}) , (b:Sentence {Sequence_number: 1, Source_Paragraph: 3,  Source: 'Burying the Dead'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
# MATCH (a:Paragraph {Sequence_number: 4, Source: 'Burying the Dead'}) , (b:Sentence {Sequence_number: 1, Source_Paragraph: 4,  Source: 'Burying the Dead'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'Burying the Dead'}) , (b:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Burying the Dead'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);

# %% [markdown]
# ## Cave Spirit Men

# %% [raw]
# CREATE (:Document
#     {
#     Title: 'Cave Spirit Men',
#     Year: '',
#     Source: 'Ancestral Dreaming Texts',
#     Contributors: 'Namurlardajaynyngku',
#     English_translation: 'Kamandarringabaya is the name of country [in Victoria Bay] and it is a Spirit Man Dreaming place. This Spirit Man is Rrumburriya; he is not Wurdaliya. The Spirit Man Dreaming belongs to that place and he has another name that is Namurlardajanyngku. He belongs to that place and he placed his hands all over the rocks in the cave that is there. Down at the shoreline are rocks that have his footprints. The Spirit Man went north to Muluwa [Cape Vanderlin] and stood high up on top of the sand dunes and he looked a long way westwards. He saw in the west another Spirit Man at Wuyakiba [to the north of the Roper River]. The Spirit Man at Wuyakiba called out to the east, ‘Kuyuuu! Kuyuuu!’ and the Spirit Man from Kamandarringabaya then had a turn and called out to the Spirit Man in the west, ‘Kaaawayi! Kaaawayi!’ They just called out to each other, that is all. The Spirit Man came back from the north and close by to Kamandarringabaya in the east is another cave that is called Warnngibangirarra; at this place, he placed himself on to the rocks. It is his Dreaming place, and he is still there.',
#     Location: 'Victoria Bay, Vanderlin Island'
#     }
# );
#
# CREATE (:Paragraph
#     {
#     Sequence_number: 1,
#     English_translation: 'Kamandarringabaya is the name of country [in Victoria Bay] and it is a Spirit Man Dreaming place. This Spirit Man is Rrumburriya; he is not Wurdaliya. The Spirit Man Dreaming belongs to that place and he has another name that is Namurlardajanyngku. He belongs to that place and he placed his hands all over the rocks in the cave that is there. Down at the shoreline are rocks that have his footprints. The Spirit Man went north to Muluwa [Cape Vanderlin] and stood high up on top of the sand dunes and he looked a long way westwards. He saw in the west another Spirit Man at Wuyakiba [to the north of the Roper River]. The Spirit Man at Wuyakiba called out to the east, ‘Kuyuuu! Kuyuuu!’ and the Spirit Man from Kamandarringabaya then had a turn and called out to the Spirit Man in the west, ‘Kaaawayi! Kaaawayi!’ They just called out to each other, that is all.',
#     English_explanation: '',
#     Source: ''
#     }
# );
#
# CREATE (:Paragraph
#     {
#     Sequence_number: 2,
#     English_translation: 'The Spirit Man came back from the north and close by to Kamandarringabaya in the east is another cave that is called Warnngibangirarra; at this place, he placed himself on to the rocks. It is his Dreaming place, and he is still there.',
#     English_explanation: '',
#     Source: ''
#     }
# );
#
# MATCH (a:Document {Title: 'Cave Spirit Men'}), (b:Paragraph {Sequence_number: 1, Source: 'Cave Spirit Men'})
# MERGE (a)-[r:Document_Paragraph_Relation]->(b);
# MATCH (a:Document {Title: 'Cave Spirit Men'}), (b:Paragraph {Sequence_number: 2, Source: 'Cave Spirit Men'})
# MERGE (a)-[r:Document_Paragraph_Relation]->(b);
#
#
# CREATE (:Sentence
#     {
#     Sequence_number: 1,
#     Source_Paragraph: 1,
#     English_translation: 'Kamandarringabaya is the name of country [in Victoria Bay] and it is a Spirit Man Dreaming place. This Spirit Man is Rrumburriya; he is not Wurdaliya.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Cave Spirit Men'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 2,
#     Source_Paragraph: 1,
#     English_translation: 'The Spirit Man Dreaming belongs to that place and he has another name that is Namurlardajanyngku.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Cave Spirit Men'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 3,
#     Source_Paragraph: 1,
#     English_translation: 'He belongs to that place and he placed his hands all over the rocks in the cave that is there. Down at the shoreline are rocks that have his footprints.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Cave Spirit Men'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 4,
#     Source_Paragraph: 1,
#     English_translation: 'The Spirit Man went north to Muluwa [Cape Vanderlin] and stood high up on top of the sand dunes and he looked a long way westwards. He saw in the west another Spirit Man at Wuyakiba [to the north of the Roper River]. The Spirit Man at Wuyakiba called out to the east, ‘Kuyuuu! Kuyuuu!’ and the Spirit Man from Kamandarringabaya then had a turn and called out to the Spirit Man in the west, ‘Kaaawayi! Kaaawayi!’ They just called out to each other, that is all.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Cave Spirit Men'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 1,
#     Source_Paragraph: 2,
#     English_translation: 'The Spirit Man came back from the north and close by to Kamandarringabaya in the east is another cave that is called Warnngibangirarra; at this place, he placed himself on to the rocks. It is his Dreaming place, and he is still there.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Cave Spirit Men'
#     }
# );
#
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'Cave Spirit Men'}) , (b:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
#
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'Cave Spirit Men'}) , (b:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
#
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'Cave Spirit Men'}) , (b:Sentence {Sequence_number: 3, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
#
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'Cave Spirit Men'}) , (b:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Cave Spirit Men'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
#
# MATCH (a:Paragraph {Sequence_number: 2, Source: 'Cave Spirit Men'}) , (b:Sentence {Sequence_number: 1, Source_Paragraph: 2,  Source: 'Cave Spirit Men'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);

# %% [markdown]
# ## Mud Crab

# %% [raw]
# CREATE (:Document
#     {
#     Title: 'Mud Crab',
#     Year: '',
#     Source: 'Ancestral Dreaming Texts',
#     Contributors: 'Nyinga',
#     English_translation: 'On the west side [of Victoria Bay] there is a very large rock; it sits there on the beach. The name of the country is Nyungkawathungka; Babangki is there in the south. This stone is the Dreaming place of the Mud Crab. The male Mud Crab placed himself as a Dreaming there, as did the female Mud Crab and the immature Mud Crabs. The male Mud Crab is behind, the female Mud Crab is in front and around the bottom are the immature Mud Crabs. The Mud Crab truly belongs to this country. The guardians for this country, the guardians for the Mud Crab, they go to the rock and they hit it and they call out the names of country and the Mud Crabs, they come out all over the place. The Mud Crab Dreaming came from the south, from the country called Liwarrantha – it is on the east bank of the Wearyan River, downstream, near the coast. The Mud Crab has songs in the songline for that country.',
#     Location: 'Victoria Bay, Vanderlin Island'
#     }
# );
#
# CREATE (:Paragraph
#     {
#     Sequence_number: 1,
#     English_translation: 'On the west side [of Victoria Bay] there is a very large rock; it sits there on the beach. The name of the country is Nyungkawathungka; Babangki is there in the south. This stone is the Dreaming place of the Mud Crab. The male Mud Crab placed himself as a Dreaming there, as did the female Mud Crab and the immature Mud Crabs. The male Mud Crab is behind, the female Mud Crab is in front and around the bottom are the immature Mud Crabs. The Mud Crab truly belongs to this country. The guardians for this country, the guardians for the Mud Crab, they go to the rock and they hit it and they call out the names of country and the Mud Crabs, they come out all over the place. The Mud Crab Dreaming came from the south, from the country called Liwarrantha – it is on the east bank of the Wearyan River, downstream, near the coast. The Mud Crab has songs in the songline for that country.',
#     English_explanation: '',
#     Source: 'Mud Crab'
#     }
# );
#
# MATCH (a:Document {Title: 'Mud Crab'}), (b:Paragraph {Sequence_number:1 , Source: 'Mud Crab'})
# MERGE (a)-[r:Document_Paragraph_Relation]->(b);
#
#
# CREATE (:Sentence
#     {
#     Sequence_number: 1,
#     Source_Paragraph: 1,
#     English_translation: 'On the west side [of Victoria Bay] there is a very large rock; it sits there on the beach. The name of the country is Nyungkawathungka; Babangki is there in the south.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Mud Crab'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 2,
#     Source_Paragraph: 1,
#     English_translation: 'This stone is the Dreaming place of
# the Mud Crab.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Mud Crab'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 3,
#     Source_Paragraph: 1,
#     English_translation: 'The male Mud Crab placed himself as a Dreaming there, as did the female Mud Crab and the immature Mud Crabs.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Mud Crab'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 4,
#     Source_Paragraph: 1,
#     English_translation: 'The male Mud Crab is behind, the female Mud Crab is in front and around the bottom are the immature Mud Crabs.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Mud Crab'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 5,
#     Source_Paragraph: 1,
#     English_translation: 'The Mud Crab truly belongs to this country.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Mud Crab'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 6,
#     Source_Paragraph: 1,
#     English_translation: 'The guardians for this country, the guardians for the Mud Crab, they go to the rock and they hit it and they call out the names of country and the Mud Crabs, they come out all over the place. The Mud Crab Dreaming came from the south, from the country called Liwarrantha – it is on the east bank of the Wearyan River, downstream, near the coast. The Mud Crab has songs in the songline for that country.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Mud Crab'
#     }
# );
#
#
#
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'Mud Crab'}) , (b:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Mud Crab'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'Mud Crab'}) , (b:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Mud Crab'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'Mud Crab'}) , (b:Sentence {Sequence_number: 3, Source_Paragraph: 1,  Source: 'Mud Crab'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'Mud Crab'}) , (b:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Mud Crab'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'Mud Crab'}) , (b:Sentence {Sequence_number: 5, Source_Paragraph: 1,  Source: 'Mud Crab'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'Mud Crab'}) , (b:Sentence {Sequence_number: 6, Source_Paragraph: 1,  Source: 'Mud Crab'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);

# %% [markdown]
# ## Mosquito and Fiddler Crab

# %% [raw]
# CREATE (:Document
#     {
#     Title: 'Mosquito and Fiddler Crab',
#     Year: '',
#     Source: 'Ancestral Dreaming Texts',
#     Contributors: 'a-Wurrkayny kulu a-Mulkangka',
#     English_translation: 'The Mosquito belongs to Anthawarra – Anthawarra is the name of the country. The Mosquito truly belongs to this place. She was there and she threw down her digging stick and water – spring waters, island water – came out. The name of the place where she threw her digging stick is Kandangabunawabija. Kumbayaluma is the name of the place where the spring waters flow down from the west; they flow down to Anthawarra. The Mosquito remains there, she placed herself as Dreaming there. A large ant hill stands in the midst of the mangroves; it is the body of the Mosquito and the name of this place is Abuyi. The old people used to sing this place with power songs and the mosquitos would come out and bite the country. They used to sing, ‘Rise up Mosquito, rise up Mosquito, bite the country, bitethe country hard!’The Fiddler Crab belongs to Nganthaa – the name of the country is Nganthaa. She belongs only to that very place; she is Wurdaliya and belongs there. At Nganthaa on the north side of the creek are many small rocks; these are the bodies of the Fiddler Crab.',
#     Location: 'east coast of South West Island'
#     }
# );
#
#
# CREATE (:Paragraph
#     {
#     Sequence_number: 1,
#     English_translation: 'The Mosquito belongs to Anthawarra – Anthawarra is the name of the country. The Mosquito truly belongs to this place. She was there and she threw down her digging stick and water – spring waters, island water – came out. The name of the place where she threw her digging stick is Kandangabunawabija. Kumbayaluma is the name of the place where the spring waters flow down from the west; they flow down to Anthawarra. The Mosquito remains there, she placed herself as Dreaming there. A large ant hill stands in the midst of the mangroves; it is the body of the Mosquito and the name of this place is Abuyi. The old people used to sing this place with power songs and the mosquitos would come out and bite the country. They used to sing, ‘Rise up Mosquito, rise up Mosquito, bite the country, bitethe country hard!’',
#     English_explanation: '',
#     Source: 'Mosquito and Fiddler Crab'
#     }
# );
#
# CREATE (:Paragraph
#     {
#     Sequence_number: 2,
#     English_translation: 'The Fiddler Crab belongs to Nganthaa – the name of the country is Nganthaa. She belongs only to that very place; she is Wurdaliya and belongs there. At Nganthaa on the north side of the creek are many small rocks; these are the bodies of the Fiddler Crab.',
#     English_explanation: '',
#     Source: 'Mosquito and Fiddler Crab'
#     }
# );
#
#
# MATCH (a:Document {Title: 'Mosquito and Fiddler Crab'}), (b:Paragraph {Sequence_number: 1, Source: 'Mosquito and Fiddler Crab'})
# MERGE (a)-[r:Document_Paragraph_Relation]->(b);
# MATCH (a:Document {Title: 'Mosquito and Fiddler Crab'}), (b:Paragraph {Sequence_number: 2, Source: 'Mosquito and Fiddler Crab'})
# MERGE (a)-[r:Document_Paragraph_Relation]->(b);
#
# CREATE (:Sentence
#     {
#     Sequence_number: 1,
#     Source_Paragraph: 1,
#     English_translation: 'The Mosquito belongs to Anthawarra – Anthawarra is the name of the country',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Mosquito and Fiddler Crab'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 2,
#     Source_Paragraph: 1,
#     English_translation: 'The Mosquito truly belongs to this place.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Mosquito and Fiddler Crab'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 3,
#     Source_Paragraph: 1,
#     English_translation: 'She was there and she threw down her digging stick and water – spring waters, island water – came out. The name of the place where she threw her digging stick is Kandangabunawabija.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Mosquito and Fiddler Crab'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 4,
#     Source_Paragraph: 1,
#     English_translation: 'Kumbayaluma is the name of the place where the spring waters flow down from the west; they flow down to Anthawarra.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Mosquito and Fiddler Crab'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 5,
#     Source_Paragraph: 1,
#     English_translation: 'The Mosquito remains there, she placed herself as Dreaming there. A large ant hill stands in the midst of the mangroves; it is the body of the Mosquito and the name of this place is Abuyi.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Mosquito and Fiddler Crab'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 6,
#     Source_Paragraph: 1,
#     English_translation: 'The old people used to sing this place with power songs and the mosquitos would come out and bite the country. They used to sing, ‘Rise up Mosquito, rise up Mosquito, bite the country, bite the country hard!’',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Mosquito and Fiddler Crab'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 1,
#     Source_Paragraph: 2,
#     English_translation: 'The Fiddler Crab belongs to Nganthaa – the name of the country is Nganthaa. She belongs only to that very place; she is Wurdaliya and belongs there.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Mosquito and Fiddler Crab'
#     }
# );
#
# CREATE (:Sentence
#     {
#     Sequence_number: 2,
#     Source_Paragraph: 2,
#     English_translation: 'At Nganthaa on the north side of the creek are many small rocks; these are the bodies of the Fiddler Crab.',
#     English_explanation: '',
#     Yanyuwa_explanation: '',
#     Yanyuwa_example: '',
#     Source:'Mosquito and Fiddler Crab'
#     }
# );
#
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'Mosquito and Fiddler Crab'}) , (b:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Mosquito and Fiddler Crab'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'Mosquito and Fiddler Crab'}) , (b:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Mosquito and Fiddler Crab'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'Mosquito and Fiddler Crab'}) , (b:Sentence {Sequence_number: 3, Source_Paragraph: 1,  Source: 'Mosquito and Fiddler Crab'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'Mosquito and Fiddler Crab'}) , (b:Sentence {Sequence_number: 4, Source_Paragraph: 1,  Source: 'Mosquito and Fiddler Crab'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'Mosquito and Fiddler Crab'}) , (b:Sentence {Sequence_number: 5, Source_Paragraph: 1,  Source: 'Mosquito and Fiddler Crab'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
# MATCH (a:Paragraph {Sequence_number: 1, Source: 'Mosquito and Fiddler Crab'}) , (b:Sentence {Sequence_number: 6, Source_Paragraph: 1,  Source: 'Mosquito and Fiddler Crab'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
# MATCH (a:Paragraph {Sequence_number: 2, Source: 'Mosquito and Fiddler Crab'}) , (b:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Mosquito and Fiddler Crab'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);
# MATCH (a:Paragraph {Sequence_number: 2, Source: 'Mosquito and Fiddler Crab'}) , (b:Sentence {Sequence_number: 2, Source_Paragraph: 1,  Source: 'Mosquito and Fiddler Crab'}),
# MERGE (a)-[r:Paragraph_Sentence_Relation]->(b);

# %% [markdown]
# ## Brolga

# %% [markdown]
# CREATE (:Document
#     {
#     Title: 'Brolga',
#     Year: '',
#     Source: 'Ancestral Dreaming Texts',
#     Contributors: 'Kurdarrku',
#     English_translation: '',
#     Location: 'plains country to the west of Manangoora'
#     }
# );
