# %%
# Text_document_section (under the chapter level)
# Encyclopedia Chapter 1

CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Languages before non-Aboriginal contact',
    Chapter_Title: 'The Country of Yanyuwa Language',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "Before white contact, the Borroloola area had six language groups: Yanyuwa, Garrwa, Binbingka, Gudanji, Wilangarra, and Marra. Only Yanyuwa has fluent speakers; some Garrwa speakers remain at Borroloola and Robinson River. Others like Binbingka and Gudanji are dormant. The history of the Walu group on Vanderlin Island perplexes the Yanyuwa. Their name might be a misinterpretation of the Yanyuwa pronoun 'alu.' The Yanyuwa, known as Wardirri to Marra, refer to Garrwa as Arrwa, while the Garrwa and Gudanji call Yanyuwa as Anyula or Yanyula.",
    Pages:'6-7'
    }
);

CREATE (:Text_Document_Section
    {
    
    Section_Title: 'The contemporary language community',
    Chapter_Title: 'The Country of Yanyuwa Language',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "Elderly fluently speak Yanyuwa, but younger generations, influenced by marriages and limited exposure, predominantly use English variants. Children vary in Yanyuwa knowledge, some close to grandparents retaining more. Yanyuwa seen as an attribute of the elders; recent initiatives spark a changing perception among the youth.",
        
    Pages:'7-9'
    }
);

CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Initial non-Aboriginal contact',
    Chapter_Title: 'The Country of Yanyuwa Language',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "The Yanyuwa people's initial contact with Makassan trepang gatherers was harmonious, exchanging labor for goods. Unlike violent colonial impacts on neighboring groups, Yanyuwa's coastal retreat spared them until modern industries encroached. English exposure started at cattle runs, trepanging bases, and in Borroloola, shaping their language by the late 1950s.",
        
    Pages:'9-11'
    }
);

CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Borroloola and the Malarndarri camp',
    Chapter_Title: 'The Country of Yanyuwa Language',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "In the 1960s, Borroloola attracted more Aboriginal people, leading to the establishment of Malarndarri, a significant Yanyuwa community. It was a stronghold of language and tradition, but epidemics in 1969 and floods in 1974 caused dislocation. This disrupted traditions, leading to a decline in Yanyuwa language fluency and cultural erosion.",
    Pages:'11-13'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'The cattle industry',
    Chapter_Title: 'The Country of Yanyuwa Language',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "During Malarndarri's prosperous era, Yanyuwa and diverse Aboriginal groups thrived in the cattle industry. Interethnic marriages led to Kriol adoption for communication. Economic constraints in the 1970s-80s caused unemployment. Returnees to Borroloola, bringing varied families, fostered Kriol and Aboriginal English as dominant household languages, shaping cultural dynamics.",
    Pages:'13-14'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Education: schools and policy',
    Chapter_Title: 'The Country of Yanyuwa Language',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "In the 1950s, the Aborigines Inland Mission established a school at the request of Yanyuwa people to teach English. Initially respecting their language, a shift in the 1970s led to English-only schooling, eroding indigenous language and culture. Modern amenities like TV further disrupted traditions, fragmenting the community. Cyclone Kathy's aftermath worsened the fragmentation due to unplanned housing.",
    Pages:'14-16'
    }
);

CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Recent trends',
    Chapter_Title: 'The Country of Yanyuwa Language',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "The Land Rights Act enabled Yanyuwa families to create outstations after a partial land claim success in 1976. However, this didn't resolve language loss and cultural issues. Senior deaths led to a decline in community solidarity. Recent projects, like 'The Song Peoples’ Sessions,' aim to revive Yanyuwa identity and culture, combating dwindling speaker numbers and transmitting cultural knowledge to younger generations. Yet, challenges persist due to limited funding and the prioritization of English in education. With a median age of twenty-one, the young Yanyuwa population requires culturally relevant education and programs to preserve their identity and well-being, as the elders' urgency to transmit cultural knowledge grows.",
    Pages:'16-20'
    }
);

# %%
# Encyclopedia Chapter 2
CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Ludwig Leichhardt',
    Chapter_Title: 'Recording Yanyuwa: People, Words and Meanings',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "In 1844, Ludwig Leichhardt encountered Yanyuwa speakers near the McArthur River. He noted their interaction, recording three Yanyuwa words. The men indicated water ahead but with unclear urgency. Leichhardt speculated they had Malay contact, inferred from their knowledge of knives and firearms, implying a desire to trade. Present Yanyuwa speakers find the phrase more imperative, wanting the white men to stop.",
    Pages:'28-29'
    }
);



CREATE (:Text_Document_Section
    {
    
    Section_Title: 'W.G. Stretton',
    Chapter_Title: 'Recording Yanyuwa: People, Words and Meanings',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "In 1888, W.G. Stretton, a Borroloola official, recorded extensive Yanyuwa vocabulary and sentences for the South Australian Museum, aligning with today's language. Despite misunderstandings due to cultural unfamiliarity, Stretton documented a powerful ceremonial song. Although its exact words remain elusive, it's identified as a 'power song,' conveying thunder and lightning to harm adversaries.",
    Pages:'29-31'
    }
);

CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Baldwin Spencer and Frank Gillen',
    Chapter_Title: 'Recording Yanyuwa: People, Words and Meanings',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "In 1901, Baldwin Spencer and Frank Gillen visited Borroloola, noting challenges with Yanyuwa interactions due to hot, humid weather and the people's independence. Despite difficulties, they gathered extensive Yanyuwa language, kinship, Dreaming stories, and terms. Spencer and Gillen's encounters revealed insights into local customs and language, preserving historical Yanyuwa knowledge.",
    Pages:'31-34'
    }
);

CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Arthur Capell',
    Chapter_Title: 'Recording Yanyuwa: People, Words and Meanings',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "Arthur Capell's 1941–42 article unveiled Yanyuwa language, recorded through collaboration with Mary Lake a-Marrawimara in the 1930s. Capell detailed Yanyuwa's intricate class system, challenging the understanding of kinship complexities. His linguistic investigations demonstrated prefix variations among genders and preserved Yanyuwa phrases, conjugations, and vocabulary, aligning with present-day usage.",
    Pages:'34-37'
    }
);

CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Marie Reay',
    Chapter_Title: 'Recording Yanyuwa: People, Words and Meanings',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "Marie Reay, an anthropologist, studied kinship in Borroloola from 1959 to 1962, despite initial difficulty with the Yanyuwa people. She recorded significant texts preserving 'old-time' Yanyuwa language.",
    Pages:'38'
    }
);

CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Ken Hale',
    Chapter_Title: 'Recording Yanyuwa: People, Words and Meanings',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "Marie Reay and Ken Hale conducted linguistic work in Borroloola. Hale extensively documented Yanyuwa, focusing on 'old-time' language and respectful kin speech. His recordings of Dreaming paths deeply impacted Yanyuwa speakers, with some texts incorporated into contemporary orthography after his approval in 1992",
    Pages:'38-39'
    }
);

CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Elwyn Flint',
    Chapter_Title: 'Recording Yanyuwa: People, Words and Meanings',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "Elwyn Flint, a linguist at the University of Queensland, extensively studied language variation across Queensland, documenting traditional Aboriginal languages like Yanyuwa. His recordings and transcriptions reside in the Fryer Library.",
    Pages:'39'
    }
);

CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Jean Kirton, Elfreda MacDonald and Yasuko Nagai',
    Chapter_Title: 'Recording Yanyuwa: People, Words and Meanings',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "Jean Kirton and Elfreda MacDonald, representing the Summer Institute of Linguistics, arrived at Borroloola in 1963 to translate the Bible into Yanyuwa. Facing community decisions and challenges, they settled on the western riverbank due to objections. Their differing approaches—linguistic focus for Jean, religious for Elfreda—marked their mission. Elfreda left temporarily, returned, and passed away in 1976, while Jean continued until her death in 1993, leaving a lasting impact on the Yanyuwa people.",
    Pages:'39-43'
    }
);

CREATE (:Text_Document_Section
    {
    
    Section_Title: 'John Bradley',
    Chapter_Title: 'Recording Yanyuwa: People, Words and Meanings',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "Arriving in Borroloola in 1980 as a teacher, John Bradley delved into the Yanyuwa language, learning from recordings and Jean Kirton's work. Jean's return in 1981 marked formal lessons on speech forms and verbs. His immersion among men on hunts and ceremonies shaped his language learning, later broadening to daily life and intimate events. In 1985, John Bradley shifted to work with Indigenous communities, exploring language, identity, and politics. Securing a grant in 1988, John Bradley collaborated with Jean's fieldwork, merging their dictionaries, an ongoing process till today.",
    Pages:'43-44'
    }
);

# %%
CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Incident at Rruwangkala [Black Rocks]’ (men’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "This short text by Pharaoh Lhawulhawu describes the theft of objects from the camp of a group of white people. Among the objects stolen was a loaded double-barrel shotgun. During a discussion about the gun, it was discharged with disastrous consequences.",
    Pages: '47-49',
    Note: "By Pharaoh Lhawulhawu; Texts collected by Marie Reay, 1959–62"
    }
);





CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Old Man Monday and the Publican',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "This story is similar to many that were told by older Yanyuwa men and women, and concerns the desire of single white men at Borroloola for Aboriginal women as sexual partners. In this story, recounted by Pharaoh Lhawulhawu, the request is made to a Yanyuwa man, but nothing goes as planned.",
    Pages:'49-55',
    Note:'By Pharaoh Lhawulhawu; Texts collected by Marie Reay, 1959–62'
    }
);



CREATE (:Text_Document_Section
    {
    
    Section_Title: 'The Story of Tommy Dodd',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "Tommy Dodd fled police custody but was pursued by tracker Pharaoh Lhawulhawu, also the narrator. This event typifies the ‘wild times,’ marked by unrestrained violence and swift justice. Escaping during a horse muster, Tommy was recaptured by Pharaoh, leading to his conviction for escape and horse theft, sentenced to six months of hard labor.",
    Pages:'55-64',
    Note:'By Pharaoh Lhawulhawu; Texts collected by Marie Reay, 1959–62'
    }
);

CREATE (:Text_Document_Section
    {
    
    Section_Title: 'The Saltwater Crocodile and the Willy Wagtail’ (men’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "A short story that describes an incident which occurred at Nguwangkila, on the Batten Creek. The story first relates the incident where the Willy Wagtail Dreaming spells out her perceived role for the Saltwater Crocodile Dreaming. The text then deals with the speaker’s view of saltwater crocodiles and their danger to people.",
    Pages:'66-69',
    Note: 'By Pharoah Lhawulhawu; Texts collected by Ken Hale, 1959'
    }
);

CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Spirit Man Dreaming',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "The Yanyuwa people call this Dreaming the ‘devil-devil,’ recounting the travels of human-like beings introducing circumcision and sub-incision. Pharaoh Lhawulhawu shares a condensed version; the complete tale spans from the west, through various locations, even across the sea to Vanderlin Island's east coast, showcasing Dreaming beings' travels, naming lands, encounters, and activities.",
    Pages: '69-74',
    Note: 'By Pharoah Lhawulhawu; Texts collected by Ken Hale, 1959'
    }
);

CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Kangaroo Dreaming',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "The Kunumbu ceremony, rooted in a significant Dreaming, once involved placing bones of deceased Rrumburriya kinspeople into hollow log coffins. Led by Pharaoh Lhawulhawu, it centered on the Kangaroo Dreaming, encountering others like the Possum and Crocodile. Johnson Timothy added context in 1991, emphasizing Borroloola's ties to the Kangaroo Dreaming for clarity.",
    Pages:'74-80',
    Note: 'By Pharoah Lhawulhawu; Texts collected by Ken Hale, 1959'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Two Short Texts in Respectful Language',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "Pharaoh Lhawulhawu presents two hypothetical conversations: one between siblings and the other between a man and his wife's maternal uncle. These texts are crucial as they capture Yanyuwa's respectful language, with minimal recordings available. Edited for clarity by older Yanyuwa speakers, they aim to preserve respectful terms occasionally omitted by Pharaoh.",
    Pages:'80-89',
    Note: 'By Pharoah Lhawulhawu; Texts collected by Ken Hale, 1959'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Burying the Dead’ (men’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "This is a short text by Arthur Narnungawurruwurru that summarises the major components of past Yanyuwa mortuary practices. These include placing the body on a burial platform, collecting the bones and placing them into a hollow log coffin. The text mentions also the kin relations who are important for undertaking this task and the final outcomes of log coffin burial in relation to the spirit of the deceased.",
    Pages:'92-94',
    Note: 'By Arthur Narnungawurruwurru; Texts collected by Jean Kirton, 1964–84'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Eating the Woman’ (men’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "It was Spencer and Gillen (1901) who first mentioned the past Yanyuwa practice of ritually eating the flesh of deceased kin. The old man who related this text, Arthur Narnungawurruwurru, was also speaking second-hand about the event. Most senior Yanyuwa men and women with whom this text was discussed all gave the name of a deceased individual who was involved in the events described and who would have been the source of information provided by the narrator. It should be noted that this text represents the only first-hand Yanyuwa account where there is an acknowledgement of the ritual practice of eating human flesh.",
    Pages:'94-95',
    Note: 'By Arthur Narnungawurruwurru; Texts collected by Jean Kirton, 1964–84'
    }
);



CREATE (:Text_Document_Section
    {
    
    Section_Title: 'The Rainbow Serpent’ (men’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "Yanyuwa tradition links the Rainbow Serpent with destructive natural forces, particularly cyclones. Pluto Wurrumungkumungku's text vividly portrays a cyclone embodied as the Rainbow Serpent, emphasizing its immense power. Yanyuwa distinguish between Dreaming and physical Rainbow Serpents, attributing specific cyclones to disturbances at sites on Sir Edward Pellew Islands, believed to house the Rainbow Serpent.",
    Pages:'95-101',
    Note: 'By Pluto Wurrumungkumungku; Texts collected by Jean Kirton, 1964–84'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Gathering for Fighting’ (men’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "This text, authored by Pluto Wurrumungkumungku, discusses two main events. Firstly, it describes large-scale duels used to settle conflicts and emphasizes the aftermath: a desire for reconciliation and the sharing of enjoyable activities, such as a significant dance performance created by the neighboring Marra people. Additionally, it provides detailed descriptions of the damage inflicted during these duels. The fight recounted in the text remains a vivid memory in Yanyuwa oral tradition, with some older Yanyuwa individuals likening it to a 'proper war' or drawing parallels to World War Two.",
    Pages:'102-109',
    Note: 'By Pluto Warramungkumungku; Texts collected by Jean Kirton, 1964–84'
    }
);



CREATE (:Text_Document_Section
    {
    
    Section_Title: 'The American Airmen’ (men’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "In 1942, an American bomber crashed in southwest Gulf country. Yanyuwa and Garrwa people searched for survivors. Pluto Wurrumungkumungku's story follows surviving airman Sergeant Grady Gaston as he trekked west through tough terrain. Only he survived. This story became the film 'ka-Wayawayama (Aeroplane Dance)' in 1992, created by the Yanyuwa and Garrwa communities.",
    Pages:'109-121',
    Note: 'By Pluto Wurrumungkumungku; Texts collected by Jean Kirton, 1964–84'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Murder on Vanderlin Island’ (men’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "In December 1927, Gilprey Walala killed two individuals on Vanderlin Island. The motive remains debated—some claim it was due to trespassing sacred land, while others suggest he was influenced to commit the act on behalf of someone upset over a relationship. Arthur Narnungawurruwurru, the storyteller, was the son of Old Lithi, present during the incident. Gilprey and his wife arrived in Borroloola in December 1927, followed by the rest of their family in March 1928. A trial occurred in April where Gilprey was charged with murder, but he was ultimately acquitted when the case went to trial in Darwin. He never returned to Borroloola and reportedly married someone from North East Arnhem Land.",
    Pages:'121-129',
    Note: 'By Arthur Narnungawurruwurru; Texts collected by Jean Kirton, 1964–84'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'The Coming of the White Man’ (men’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "Pharaoh Lhawulhawu's text recounts the Yanyuwa people's first encounter with white men, where they initially mistook horses for dogs. It delves into the development of Borroloola township, detailing its construction. Later, the text addresses frontier violence, specifically the massacre of Gudanji people. Notably, the storytelling style is intriguing, described as 'rough' or 'heavy' Yanyuwa. The speaker's use of singular forms instead of plural markers, reminiscent of older Yanyuwa speakers, is a linguistic point of interest discussed further in relation to texts linked to Dreaming Ancestors.",
    Pages:'130-140',
    Note: 'By Pharoah Lhawulhawu; Texts collected by Jean Kirton, 1964–84'
    }
);










CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Pubic Coverings and Hair String’ (women’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "In 1980, elderly individuals retained knowledge of crafting items from pre-colonial times. As part of preparations for a dance festival, older men and women created accessories like pubic coverings, hair strings for belts, and head-dresses. Annie Isaac a-Karrakany shared this information with Yasuko Nagai while showcasing one of the women's pubic coverings.",
    Pages:'141-143',
    Note: 'By Annie Isaac aKarrakayn; Texts collected by Yasuko Nagai, 1980–81'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'When Thelma Douglas Broke Her Leg’ (men’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "Thelma Douglas a-Walwalmara, an active advocate for two-way education, served as an adult educator and mentor in Borroloola. During the cold season of 1980, while fishing with her family at Ryan’s Bend on Batten Creek, she encountered a non-threatening snake while perched on an overhanging branch. Startled, she jumped, resulting in a severe leg injury—fracturing both her tibia and fibula, causing them to break through the skin. Despite her initial fear, the snake turned out to be harmless. This incident was recounted by Don Miller Manarra.",
    Pages:'143-146',
    Note: 'By Don Miller Manarra; Texts collected by Yasuko Nagai, 1980–81'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Hunting for Long-Necked Turtles',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "Dinah Norman a-Marrngawi's story showcases everyday speech and storytelling. It revolves around a trip downstream from Borroloola to hunt long-necked turtles on Kangaroo Island. This narrative style is known as a 'short way' of speaking, containing widely understood information. However, the speaking style changes in the last paragraph as Dinah provides specific instructions to Yasuko about the name of the Landing.",
    Pages:'146-149',
    Note: 'By Dinah Norman a-Marrngawi; Texts collected by Yasuko Nagai, 1980–81'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'The Jabiru, the Black-Nosed Python and the Dingo’ (women’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "This text, by Bella Charlie a-Marrajabu, is a very simple retelling of a Dreaming narrative that belongs to the Wuyaliya clan. It is typical of the way a story might be told quickly to children or to people who are not really familiar with Yanyuwa country and Law. A much more complex form of this story is given in the Dreaming narratives section of this volume (Chapter 5).",
    Pages:'149-152',
    Note: 'By Bella Charlie a-Marrajabu; Texts collected by Yasuko Nagai, 1980–81'
    }
);







CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Hong Kong Flu Epidemic at Malarndarri Camp, 1969’ (women’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "In 1969, during local races in August, two Yanyuwa people from Darwin flew to Borroloola. One of them showed symptoms of a severe Hong Kong Flu on the flight, leading to its rapid spread through the camps. Eight deaths occurred in the following month, prompting the abandonment of the Malarndarri camp. The Yanyuwa moved across the McArthur River, setting up camps along its western banks. Despite further moves due to more deaths, Malarndarri camp remains a poignant symbol of Yanyuwa strength and resilience before government welfare control. The relocation to the western bank is viewed as disastrous. Some senior Yanyuwa individuals attribute the flu epidemic to sorcery or damage to a Flu Dreaming site on Bing Bong Station caused by cattle or stockmen.",
    Pages:'159-166',
    Note: 'By Eileen McDinny a-Manankurrmara; Texts collected by John Bradley, 1982–2013'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'The Spirit and the Old Lady’ (women’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "The Yanyuwa believe in spirit beings that can influence the mortal world. Eileen McDinny a-Manankurrmara's text recounts an incident where a woman was attacked by a spirit named Jurdurrubanji, known for its long penis and intense desire for women. It also emphasizes the spirits' jealousy toward their land, disapproving of people entering it for hunting purposes.",
    Pages:'166-171',
    Note: 'By Eileen McDinny a-Manankurrmara; Texts collected by John Bradley, 1982–2013'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Majarla and the Saltwater Crocodile Attack’ (women’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "Jack Majarla was a big man in Yanyuwa society – big in stature and, for  many years, a leader of the a-Kunabibi ceremony. He was also one of the  few men to have survived a saltwater crocodile attack. The narrator, Dinah Norman a-Marrngawi, relates the story of the circumstances  surrounding the attack and the events that enabled Jack to escape and be  rescued.",
    Pages:'172-179',
    Note: 'By Dinah Norman a-Marrngawi; Texts collected by John Bradley, 1982–2013'
    }
);





CREATE (:Text_Document_Section
    {
    
    Section_Title: 'The Death of the Old Man and What Happened’ (women’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "In past times, taking care of the dead was a matter totally in control of  the Yanyuwa people; these days, this is not the case and the old rituals  that occurred immediately after a person’s death no longer take place.  This text, by Eileen McDinny a-Manankurrmara, describes in detail  what once happened just prior to, and immediately after, the death of an  individual. It mentions, among other things, the singing of song cycles,  enquiries into possible sorcery, the wrapping of the body and its  placement on a platform, the search for signs giving an indication as to  who was responsible for the death, and actions undertaken by the  deceased person’s living relatives after the body was removed from the  camp.",
    Pages:'179-188',
    Note: 'By Eileen McDinny a-Manankurrmara; Texts collected by John Bradley, 1982–2013'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Path of the Mambaliya-Wawukarriya Songlines’ (men’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "A key component of a number of Yanyuwa ceremonies is the singing of  songlines. These are songs that tell of the travels of certain Dreamings  over the country, including what they saw, who they met and the names  of the country that was traversed. The narrator of this text, Dinny  McDinny Nyilba, is one of the senior holders of the songline under discussion, and his telling of the songline path is interesting from the  point of view of the language used. It describes in detail how the singers  of song cycles ‘carry the song’ and ‘put it down’, and how the song itself  travels, as if it has a life of its own.",
    Pages:'188-204',
    Note: 'By Dinny McDinny Nyilba; Texts collected by John Bradley, 1982–2013'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'My Aunty Wambadurna Ran Away’ (women’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "In Yanyuwa, the term wunji means ‘to run away with one’s lover’ or ‘to  elope’. Such stories well told are filled with wicked delight and always  surrounded in commentary by the various people listening to the story.  The normal structure of these stories is that the lovers run away and then  are found and brought back to face the family; often there was violence  as they were punished. This story is quite simply told, by Bella Charlie a\x02Marrajabu, of a woman running away and of her father going to find her  and bring her back to her original husband. This feat did, however,  involve a walk all the way from Borroloola to Manangoora and back  again.",
    Pages:'204-209',
    Note: 'By Bella Charlie a-Marrajabu; Texts collected by John Bradley, 1982–2013'
    }
);





CREATE (:Text_Document_Section
    {
    
    Section_Title: 'The Young People’ (men’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "Pyro Dirdiyalma was one of the best songmen in Yanyuwa society. He  was a proud man and was concerned to pass on knowledge to the  younger generation. This text by Pyro highlights his concern and the  choices that have to be weighed up by the young people. Do they wish to  learn the songlines or are they going to leave them?",
    Pages:'209-214',
    Note: 'By Pyro Dirdiyalma; Texts collected by John Bradley, 1982–2013'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'The Giving of a Promised Wife’ (women’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "The text discusses the Yanyuwa tradition of promising baby girls to older men, which no longer happens in modern society. Young people now choose their partners, with objections arising only if relationships are too closely related. It highlights the importance of penis blood in rituals, used historically for painting a promised wife and during burial ceremonies.",
    Pages:'215-218',
    Note: 'By Eileen McDinny a-Manankurrmara; Texts collected by John Bradley, 1982–2013'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Concerning the Two Men Who Drowned’ (women’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "The story, by Amy Friday a-Bajamalanya and Bella Charlie a-Marrajabu, delves into relationships, sorcery, death practices, and the spirit world, focusing on the drowning of two men in a canoe incident. Yanyuwa attributed the deaths to delayed sorcery and an encounter with a false killer whale. Delayed sorcery involves directing victims to perform an activity that leads to their death, as seen when the victims were instructed to hunt for dugong and died during the task. The Yanyuwa view whales as potentially dangerous offspring of Rainbow Serpents. Additionally, the text touches on Yanyuwa beliefs about the deceased communicating with the living.",
    Pages:'219-244',
    Note: 'Amy Friday a-Bajamalanya and Bella Charlie a-Marrajabu; Texts collected by John Bradley, 1982–2013'
    }
);





CREATE (:Text_Document_Section
    {
    
    Section_Title: 'The Death of Horace Foster at Manangoora’ (women’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "Horace Foster and Bill Harney senior were close friends who lived and worked together at Manangoora in the late 1920s and early 1930s, primarily in the saltpans. When a mishap occurred where Horace tried to remove a jammed bullet from a gun and it exploded, severely injuring his leg, a messenger traveled about 90 kilometers west to Borroloola for help. At the time, only Ruth Heathcock and her assistant Bessie Marshall were present, so they embarked on a canoe journey to try to save Horace. Despite their efforts, they couldn't reach him in time, and Horace passed away as a result of the accident in March 1941. This account also mentions Ted Heathcock, a policeman in Borroloola, and Roger Jose, another prominent figure in the Territory and Borroloola community.",
    Pages:'244-257',
    Note: 'By Bessie Marshall a-Kithibula; Texts collected by John Bradley, 1982–2013'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Journey East, 1988’ (1) (women’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "In July 1988, a large group of senior Yanyuwa men and women decided  to take their sons, daughters and grandchildren back through country  that they had walked through since just after World War Two. The walk  started on the east bank of the McArthur River, at the old, important  camp of Malarndarri. The focus of this walk was to reconstruct the  taking of circumcision initiates to Manangoora, 96 kilometres to the  east, for their ceremonies. The speaker of this narrative, Eileen McDinny  a-Manankurrmara, did not undertake walk herself but she provided  important support for those who did and she met them when they finally  arrived at Manangoora. This narrative describes her role in the events.",
    Pages:'257-266',
    Note: 'By Eileen McDinny a-Manankurrmara; Texts collected by John Bradley, 1982–2013'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Journey East, 1988’ (2) (women’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "Dinah Norman a-Marrngawi was one of the last women to walk the  track between Borroloola and Manankurra, and she was one of the  leaders for the 1988 walk. In her narrative, Dinah describes the country  that was travelled though, and then on coming closer to Manangoora her  interaction with her cousin Eileen McDinny, the speaker of the first text  concerning this walk. On completion of the walk, Dinah, Eileen and a  group of other women composed a number of song poems about the  event. These song poems are included in this volume in the chapter on  Yanyuwa song poetry (Chapter 4). A film was also made of this walk; it is titled Buwarrala Akarriya (Journey East), and much of the conversation that is represented here can  be seen and heard on this film.",
    Pages:'266-276',
    Note: 'By Dinah Norman a-Marrngawi; Texts collected by John Bradley, 1982–2013'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Journey East, 1988’ (3) (women’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "Before starting a walk, a decision was made to feature the significance of food derived from the cycad palm in a film. While on the walk, the toxic cycad palm fruit was processed to make it safe for consumption. After the walk concluded, the prepared food was made ready to eat. Eileen McDinny a-Manankurrmara shared this story while she prepared the cycad fruit, highlighting its crucial role in Yanyuwa culture. Additionally, it emphasizes how both Indigenous and non-Indigenous people relied on this food for survival in historical times.",
    Pages:'276-286',
    Note: 'By Eileen McDinny a-Manankurrmara; Texts collected by John Bradley, 1982–2013'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Murder on Vanderlin Island’ (women’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "This story covers the same events as described by Arthur  Narnungawurruwurru, who was recorded by Jean Kirton. Ida Ninganga  was a small child on the island when the event took place, and the people  killed were her close relatives. This text is included as a comparison of  how oral tradition holds much information about a single event. Ida is  remembered as a feisty old woman and this story is the only one of the  many that she told where she consented to being recorded.",
    Pages:'286-292',
    Note: 'By Ida Ninganga; Texts collected by John Bradley, 1982–2013'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Searching for the American Airmen and Finding the Aeroplane Dance’ (men’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "This story is related to the one told by Pluto Wurrumungkumungku to  Jean Kirton and given already above. It details events surrounding the  search for the missing American airmen in 1942–43. The narrator of this  story, Ron Ricket Murundu, went on the search and was accompanied  by his father’s brother, Frank Karrijiji. The story begins by detailing  some of the search and the encounter with search planes, and then it  moves on to the revealing and performing of the Aeroplane Dance as it  was composed or found by Frank. This song and the accompanying  dance are still considered to be one of the peaks in the remembered  corpus of such works in Yanyuwa culture. The lyrics as composed by  Frank Karrijiji are included in the chapter on Yanyuwa song poetry  (Chapter 4). A comparison of this text and the song poetry reveals the  sources for some of the song verses. A year after recording this story in  1988, Ron Ricket died. In 1989, preparations began for the film  concerning the events surrounding the crash of the Liberator bomber,  the search for the missing men and the composition of the song and  dance. Before he died, Ron had instructed his relatives not to let his  impending death hinder the making of the film. This film was  completed in 1992 and is titled ka-Wayawayama (Aeroplane Dance).",
    Pages:'293-306',
    Note: 'By Ron Ricket Murundu; Texts collected by John Bradley, 1982–2013'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Runaway Lovers and Their Punishment’ (women’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "This story was told by Eileen McDinny a-Manankurramara after she had  heard Bella Charlie tell her story of her aunty who ran away with her  lover (see above). Eileen told this story to emphasise how wrong such  behaviour was once seen to be. This is a hypothetical story about two  people who run away as lovers, the search for them and the punishment  that took place after they were found.",
    Pages:'306-312',
    Note: 'By Eileen McDinny a-Manankurramara; Texts collected by John Bradley, 1982–2013'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'The Runaway Woman and the Revenge Party’ (men’s language)',
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "Old Tim Timothy Rakawurlma's narrative, supplemented by Old Banjo Dindalhi, Old Pyro Dirdiyalma, and Judy a-Marrngawi, recounts a revenge journey from Manangoora to Queensland in 1887. Trigger (1992) and a 1887 newspaper align with some events. Tim's story, triggered by a query on stone tools, highlights a-wulkangu's lethal nature. The tale, enriched by various witnesses over time, was finalized in 2013 with additional enthusiasts.",
    Pages:'313-351',
    Note: 'By Old Tim Timothy Rakawurlma with assistance by Old Banjo  Dindalhi, Old Pyro Dirdiyalma, Judy a-Marrngawi, Johnson Timothy, Whylo McKinnon, Steve Johnston and  Annie a-Karrakayn; Texts collected by John Bradley, 1982–2013'
    }
);

# %%
CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Walaba and a-kurija: fun songs composed by men and women',
    Chapter_Title: 'Yanyuwa Song Poetry',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "",
    Pages:'352-361',
    Note: 'Fun songs composed by men and women'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Yanyuwa Song Poetry during Makassan and European trepanging period',
    Chapter_Title: 'Yanyuwa Song Poetry',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "",
    Pages:'361',
    Note: ''
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Songs of European contact',
    Chapter_Title: 'Yanyuwa Song Poetry',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "",
    Pages:'362-364',
    Note: ''
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Songs of being on country',
    Chapter_Title: 'Yanyuwa Song Poetry',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "",
    Pages:'365-372',
    Note: ''
    }
);

CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Songs of love and longing',
    Chapter_Title: 'Yanyuwa Song Poetry',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "",
    Pages:'372-379',
    Note: ''
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Songs regarding the World War Two, 1942',
    Chapter_Title: 'Yanyuwa Song Poetry',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "",
    Pages:'379-384',
    Note: ''
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Songs regarding Kalwanyarra, Travelling with the Spirit People, 1958',
    Chapter_Title: 'Yanyuwa Song Poetry',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "",
    Pages:'384-388',
    Note: ''
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Summer Institute of Linguistics, Bible Translators Workshop, Darwin, 1987',
    Chapter_Title: 'Yanyuwa Song Poetry',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "",
    Pages:'388-389',
    Note: 'By Jemima Miller a-Wuwarlu and Bella Charlie a-Marrajabu'
    }
);

CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Buwarrala Akarriya, Journey Eastwards, 1988',
    Chapter_Title: 'Yanyuwa Song Poetry',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "",
    Pages:'389-392',
    Note: 'All verses jointly by Annie Isaac a-Karrakany, Dinah Norman a\x02Marrngawi, Eileen McDinny a-Manankurrmara, Jemima Miller a\x02Wuwarlu and Thelma Douglas a-Walwalmara'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Songs regarding Warnarrwarnarr-Barranyi (Borroloola No. 2 Land Claim), 1992',
    Chapter_Title: 'Yanyuwa Song Poetry',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "",
    Pages:'393',
    Note: ''
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Songs regarding Lhukannguwarra (Borroloola No. 3 Land Claim), 1999',
    Chapter_Title: 'Yanyuwa Song Poetry',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "",
    Pages:'394-395',
    Note: ''
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Karranyjarla, Lullabies',
    Chapter_Title: 'Yanyuwa Song Poetry',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "",
    Pages:'395-396',
    Note: ''
    }
);

# %%
CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Barracuda',
    Chapter_Title: 'Ancestral Dreaming Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "The Barracuda, originating from the north, embarked on a journey along the McArthur River. Without songs but with ceremonial calls, she named various lands as she moved upstream. From Rabunthu and Ngulunankurra, she continued, marking Lakarrijila and Limandarra until she reached Wulijirra. Passing landmarks like Ngarrijinda and Mungkungadarrka, she heard calls from creatures like the Chestnut Rail and the Water Rat. The journey proceeded with stops at Mungkumurndaa and Wukunbukun, where she placed spirit children, causing the river's surface to ripple. Her path led to Wukarrala, Wanjiya, and Wulkuwulku, where she danced powerful ceremonies alone. Finally, reaching Lubundalha, she transformed into a large coolibah tree, now fallen but remembered with reverence.",
    Pages:'406-409',
    Note: 'Yijan: a-Mukarra; Ngalki: Wuyaliya; Awara: McArthur River and Kangaroo Island'
    }
);



CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Black-Nosed Python',
    Chapter_Title: 'Ancestral Dreaming Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "The story narrates the journey of the Black-Nosed Python, an entity belonging to different clans in various Aboriginal languages. Originating from Kulabanji in Marra country, she traveled with companions across seas, performing ceremonies at different reefs and locations. As she moved eastward, her essence shifted between clans, marking the places she passed through and naming various Dreamings or ceremonial sites. Struggling with illness along the way, she warned against a specific area, placing the flu as a Dreaming there, before finally resting at Abalawiji, a lagoon on the west bank of a river, where the Yalkawarru ceremony is held.",
    Pages:'409-413',
    Note: 'Yijan: a-Buburna; Ngalki: Wurdaliya; Awara: Limmen Bight, Bing Bong and Carrington Channel'
    }
);



CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Brolga',
    Chapter_Title: 'Ancestral Dreaming Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "The story traces the journey of the Brolga, a majestic bird, across various lands. Originating from Dalwajinda in the east, he traveled through Wamarla, Walmunda, and Birrbirrirna, dancing in each place. He recognized Wubunjawa in the west as his true home, creating a lagoon named Wubunjawa and establishing himself as a Dreaming figure there. At Lurriyarri, he convinced a Rock Cod to return to the sea and performed another ceremony, Kulyukulyu. Eventually, after spiraling upwards and shedding feathers at Kumbarinkanyajulaki, he landed in Warrkujaja, the land of the Marra people in the west.",
    Pages:'413-415',
    Note: 'Yijan: Kurdarrku; Ngalki: Mambaliya-Wawukarriya; Awara: plains country to the west of Manangoora'
    }
);



CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Cave Spirit Men',
    Chapter_Title: 'Ancestral Dreaming Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "In Victoria Bay, there's a country called Kamandarringabaya, a significant place in the Spirit Man Dreaming story. The Spirit Man, Rrumburriya (also known as Namurlardajanyngku), has ties to this area, marking his presence by placing his hands on cave rocks and leaving footprints on the shoreline. He traveled north to Muluwa (Cape Vanderlin) where he observed another Spirit Man to the west at Wuyakiba (north of the Roper River). They communicated through calls but merely exchanged greetings. On his return, close to Kamandarringabaya, he settled at another cave called Warnngibangirarra, making it his Dreaming place where he remains.",
    Pages:'415-416',
    Note: 'Yijan: Namurlardajaynyngku; Ngalki: Rrumburriya; Awara: Victoria Bay, Vanderlin Island'
    }
);




CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Chicken Hawk and the Crow',
    Chapter_Title: 'Ancestral Dreaming Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "The Crow came from Marrinybul in the east to Rruwangkala (Black Rocks) with her children. Meanwhile, the Chicken Hawk arrived from Yijiwunyara in the east to Wudalwanga. The Crow had water, and the Chicken Hawk possessed fire. They argued over exchanging these elements—Crow wanted fire for cooking, while Chicken Hawk desired water to drink. Their dispute turned into a fight, resulting in Crow scattering the fire north and south, while Chicken Hawk spilled the water east and west. This conflict led to the division: today, some groups use fire for cooking (Wuyaliya and Wurdaliya people), and others use water for drinking (Mambaliya and Rrumburriya people).",
    Pages:'417-418',
    Note: 'Yijan: Malarrkarrka kulu a-Wangka; Ngalki: Wuyaliya; Awara: Black Rocks and the plains country to the east'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Dingo',
    Chapter_Title: 'Ancestral Dreaming Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "The passage narrates the journey of the Dingo from Bunawuna in the south to various locations in the north. Along the way, he encounters different animals and Dreamings, engages in ceremonies, and interacts with creatures like the Jabiru and Rainbow Serpents. The story describes his travels, interactions, and even his longing for a female Dingo. Eventually, the Dingo reaches the sea, where his songs and Dreamings find their place, resonating deeply in the depths of the ocean.",
    Pages:'419-425',
    Note: 'Yijan: Wurrundurla; Ngalki: Wuyaliya; Awara: Fletcher Creek down to the mouth of the Crooked River'
    }
);


CREATE (:Text_Document_Section
    {
    
    Section_Title: 'Dugong Hunters',
    Chapter_Title: 'Ancestral Dreaming Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "The passage narrates the journey of Dugong Hunters from Warnnguluyu to Wunubarryi. They traveled in bark canoes, encountering various places along the way, breaking a limestone rock at Wubukabukala and carrying its pieces. Some stayed behind at different locations due to age or exhaustion, while others continued northward. They named numerous places, encountering Dreamings and sacred sites, eventually reaching Wunubarryi in the west, where they settled, leaving their marks and establishing connections between various landmarks. The story also recounts instances of loss and separation among the Dugong Hunters during their expedition.",
    Pages:'426-436',
    Note: 'Yijan: li-Maramaranja; Ngalki: Rrumburriya; Awara: Vanderlin Island, North Island, Skull Island, White and  Black Craggy Islands, West Island, Rosie Creek mouth, Limmen  Bight and Mount Young'
    }
);


CREATE (:Text_Document_Section
  {
  
  Section_Title: 'Groper',
  Chapter_Title: 'Ancestral Dreaming Texts',
  Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
  Description: "The passage narrates the journey of the Groper, a mythical figure, traveling across various locations. Starting from Ngurdurri, she moves eastward, carrying items symbolic of her identity. She encounters Baby Dreamings but leaves due to their loud cries, seeking her own country. Eventually, she reaches Wumanthala, sings for the land, and meets the Jabiru Dreaming at Minyadawiji. Her journey continues through different sacred places, where she leaves imprints of her presence and places various Dreamings. As she travels westward, she dances her ceremonial rituals, leaving marks and establishing connections with different Dreamings and sacred sites. The narrative ends as she arrives at a lagoon called Wardangaja in the west.",
  Pages:'436-441',
  Note: 'Yijan: a-Kuridi; Ngalki: Wuyaliya; Awara: near old Doomadgee Mission, South West Island and Roper River'
  }
);

CREATE (:Text_Document_Section
  {
  
  Section_Title: 'Hammerhead Shark',
  Chapter_Title: 'Ancestral Dreaming Texts',
  Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
  Description: "The Hammerhead Shark and two Long-Tailed Stingrays journeyed from Wuyakiba in the west. They met the Tiger Shark from Dumbarra carrying cycad food. The Tiger Shark headed south, while the Hammerhead Shark sought his own land. They reached Lardinyma, where the Hammerhead Shark created a creek and a well before turning into trees.",
  Pages:'441-443',
  Note: 'Yijan: Warriyangalayawu; Ngalki: Rrumburriya; Awara: north of the Roper River mouth, Vanderlin Rocks and Vanderlin Island'
  }
);


CREATE (:Text_Document_Section
  {
  
  Section_Title: 'Hill Kangaroo',
  Chapter_Title: 'Ancestral Dreaming Texts',
  Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
  Description: "The Hill Kangaroo journeyed from Bamburrangu to Burrulula, creating landmarks and ceremonies along the way. He established caves, lagoons, and Dreaming sites like Liyalkangka and Kunumbu ceremony grounds. His travels led him to Malarndarri, Wandangula, and finally, he became part of Mabunji, a stone in the river at Warralungku.",
  Pages:'443-445',
  Note: 'Yijan: Nangurrbuwala; Ngalki: Rrumburriya; Awara: Cape Crawford, Borroloola, Malarndarri Old Camp, Police Lagoon and the McArthur River Crossing'
  }
);

CREATE (:Text_Document_Section
  {
  
  Section_Title: 'Mosquito and Fiddler Crab',
  Chapter_Title: 'Ancestral Dreaming Texts',
  Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
  Description: "The Mosquito, native to Anthawarra, brought forth spring waters by throwing her digging stick at Kandangabunawabija. She embodies the land at Abuyi's ant hill. In Nganthaa, the Fiddler Crab is exclusive to that region, with small rocks signifying their presence on the north side of the creek.",
  Pages:'446-447',
  Note: 'Yijan: a-Wurrkayny kulu a-Mulkangka; Ngalki: Wurdaliya; Awara: east coast of South West Island'
  }
);



CREATE (:Text_Document_Section
  {
  
  Section_Title: 'Mud Crab',
  Chapter_Title: 'Ancestral Dreaming Texts',
  Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
  Description: "Nyungkawathungka by Victoria Bay hosts the Dreaming place of the Mud Crab, marked by a large rock. Male, female, and immature Mud Crabs are represented on this stone. Guardians invoke the Mud Crab's presence by hitting the rock and calling out country names, originating from Liwarrantha to the south.",
  Pages:'447-448',
  Note: 'Yijan: Nyinga; Ngalki: Rrumburriya; Awara: Victoria Bay, Vanderlin Island'
  }
);


CREATE (:Text_Document_Section
  {
  
  Section_Title: 'Rain and Rib Bones of the Rainbow Serpent',
  Chapter_Title: 'Ancestral Dreaming Texts',
  Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
  Description: "The Rain Dreaming at Larlbangka and Wawurranda, downstream from Marrinybul, embodies the heavy storms, gentle rains, Stinking Turtle, and Dollar Bird. Former leaders sang rain with powerful songs, now lost with their passing. Milundurrala hosts the Rainbow Serpent, his blood painting the red ground, originating from Lingajakarula in the south.",
  Pages:'448-450',
  Note: 'Yijan: Wabuda kulu na-lalurr ki-Bujimalawu; Ngalki: Mambaliya-Wawukarriya; Awara: McPherson Creek and country to the west of Manangoora'
  }
);



CREATE (:Text_Document_Section
  {
  
  Section_Title: 'The Rainbow Serpent Belonging to Walala and the Mouth of the Eagle Ray at Wulunthurr',
  Chapter_Title: 'Ancestral Dreaming Texts',
  Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
  Description: "Walala, a significant lagoon known as Lake Eames, holds the Tiger Shark's song from the south, chanted by elders at daybreak. It also houses a live Rainbow Serpent. Cautionary tales warn against the southern end due to the presence of the dangerous Rainbow Serpent, considered a stone. Wulunthurr, near Yukuyi, embodies the Eagle Ray Dreaming, capable of summoning storm winds through ancient power songs.",
  Pages:'450-451',
  Note: 'Yijan: Bujimala jibiya Walala kulu Manumanu na-mulu jibiya ; Wulunthurr; Ngalki: Rrumburriya Awara: Lake Eames and southern Vanderlin Island'
  }
);


CREATE (:Text_Document_Section
  {
  
  Section_Title: 'Rock Cod',
  Chapter_Title: 'Ancestral Dreaming Texts',
  Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
  Description: "Jarrka (Sharker Point) is the Wawukarriya people's peninsula, home to the Rock Cod Dreaming. Driven from Lurriyarri by the Brolga Dreaming, the Rock Cod journeyed naming places like Wangkuwala, Thayinda, Rudanbabanda, Wikalwikala, and Lidambuwa. Finally settling at Liwarriya, where he remains; a well symbolizing his mouth, guarded by an Olive Python, sustains the water, making it his eternal abode.",
  Pages:'452-453',
  Note: 'Yijan: Wangkuwa; Ngalki: Mambaliya-Wawukarriya; Awara: Sharker Point'
  }
);



CREATE (:Text_Document_Section
  {
  
  Section_Title: 'Saltwater Crocodile and Willy Wagtail',
  Chapter_Title: 'Ancestral Dreaming Texts',
  Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
  Description: "In Yalku-Yalku, the Hill Kangaroo unearthed the Saltwater Crocodile while searching for water. Conversing, they revealed their destinations. The Crocodile, heading to Nguwangkila, faced hostility from a furious Willy Wagtail, predicting its dangerous nature. Since then, the Crocodile, lurking at Nguwangkila, devours various creatures, earning mistrust. The site remains a significant Dreaming place.",
  Pages:'453-456',
  Note: 'Yijan: Mardumbarra kulu a-Kijirrikijirri; Ngalki: Rrumburriya; Awara: Batten Creek'
  }
);


CREATE (:Text_Document_Section
  {
  
  Section_Title: 'Sea Turtle and the Osprey',
  Chapter_Title: 'Ancestral Dreaming Texts',
  Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
  Description: "The Osprey claimed Wurdaliya country in the west, confronted the Sea Turtle Dreaming at Riyinbirr, and attacked, scattering eggs. Enraged, he chased and killed them across diverse landmarks. The chase ended with their demise, their remains marking territories. Osprey's aggression culminated at Jalma after devouring the turtles.",
  Pages:'456-461',
  Note: 'Yijan: Wundanyuka kulu Jujuju; Ngalki: Wurdaliya; Awara: Pine Creek, West Island, Watson Island and North Island'
  }
);



CREATE (:Text_Document_Section
  {
  
  Section_Title: 'Spirit People',
  Chapter_Title: 'Ancestral Dreaming Texts',
  Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
  Description: "The text recounts a journey of Spirit People from initiation ceremonies to creating Dreaming sites, traversing landscapes, placing sacred objects, encountering animals, and ending in conflict. They moved eastward, met diverse beings, and finally, the leader, frustrated by others, unleashed fire that consumed all but him, settling in Nhuriki.",
  Pages:'462-477',
  Note: 'Yijan: Ngabaya; Ngalki: Wurdaliya; Awara: Frog Rock, Jump Up, Goose Lagoon, Foelsche River, Rocky, country to the southeast of the Fat Fellows Creek, Sandy Head and parts of the east coast of Vanderlin Island'
  }
);




CREATE (:Text_Document_Section
  {
  
  Section_Title: 'Spotted Nightjar',
  Chapter_Title: 'Ancestral Dreaming Texts',
  Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
  Description: "From Rruwangkala, the Spotted Nightjar embarked upstream carrying Ngajakurra ceremony. Passing Ngarninja, Namaru, Wujulakinda, Wuwayanda, Rarrungkul, Wardawardala, Limuyakakala, Liwirriyirla, to Milibundurra, meeting Whirlwind Rainbow Serpent. Serpent heads west to Mirrimiriji, Nightjar settles at Nyamurri after finding Rrungun Creek, ending his journey.",
  Pages:'478-480',
  Note: 'Yijan: Yilayi; Ngalki: Mambaliya; Awara: Black Rocks, King Ash Bay and Duck Island'
  }
);



CREATE (:Text_Document_Section
  {
  
  Section_Title: 'Stone Dreaming',
  Chapter_Title: 'Ancestral Dreaming Texts',
  Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
  Description: "The Stone Dreaming journeyed from Yililyi to Muluwa, dropping stones of significance. She placed stones in Muluwa and Wumbuwa, defining laws. Moving west, she named locations like Wubula and Wuluwarra. Dropping stones along the way, she made wells and landmarks. Her power songs protected her dangerous Dreaming.",
  Pages:'480-484',
  Note: 'Yijan: a-Kuwaykuwayk; Ngalki: Rrumburriya; Awara: Calvert River, Robinson River, Vanderlin Island, Willy Islet and Centre Island'
  }
);


CREATE (:Text_Document_Section
  {
  
  Section_Title: 'Tiger Shark',
  Chapter_Title: 'Ancestral Dreaming Texts',
  Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
  Description: "In the land of Ganggalida people, a Tiger Shark guarded cycad food at Dumbarra. Ridiculed, he fought other fish, claiming the food. Journeying, he tried sharing at Wurlma and Nungkariwurra, but the Rock Wallaby refused. He placed food along rivers, bestowing power songs. Tiger Shark's significance to Rrumburriya people spanned vast territories, holding vital Law and songs.",
  Pages:'484-491',
  Note: 'Yijan: Ngurdungurdu; Ngalki: Rrumburriya; Awara: near Doomadgee, Vanderlin Rocks, Vanderlin Island, Wearyan River and Manangoora'
  }
);


CREATE (:Text_Document_Section
  {
  
  Section_Title: 'Two Initiates and the Rainbow Serpent',
  Chapter_Title: 'Ancestral Dreaming Texts',
  Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
  Description: "In ancient times, two young boys undergo initiation after dancing all night in the Dreaming at Wumarndarralamba. Hungry, they venture westward, naming places they encounter. They encounter a Rainbow Serpent, face trials, angering it. Ultimately, the Serpent banishes them to the northern sea as stone figures.",
  Pages:'491-510',
  Note: 'Yijan: Rduwarrawujara kulu Bujimala; Ngalki: Rrumburriya; Awara: Five Mile Bend, to Ngambingambi Rockhole, McArthur River to Centre Island, Horn Islet, Observation Island, Pearce Islet and Urquhart Island'
  }
);


CREATE (:Text_Document_Section
  {
  
  Section_Title: 'Wedge-Tailed Eagle and Crow',
  Chapter_Title: 'Ancestral Dreaming Texts',
  Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
  Description: "The Wedge-Tailed Eagle and the Crow, known as the Mambaliya, originated from Jangkala in the south. They journeyed to Kujulhuwa and then Janbamurruku, where they surveyed the land to the east. They settled in Janba near Yalakunji, making nests in the Garrwa people's country. However, they encountered Rainbow Serpents who claimed the territory and forced them to move northwest. The Crow's nest tipped over during the journey, and they eventually landed at Marrinybul, significant for the Mambaliya. While the Wedge-Tailed Eagle stayed, the Crow continued westward to Rruwangkala in the McArthur River.",
  Pages:'510-512',
  Note: 'Yijan: a-Kilyarrkilyarr kulu a-Wangka; Ngalki: Mambaliya; Awara: Barkly Tablelands, top of the McArthur River, Robinson River and McPherson Creek'
  }
);


CREATE (:Text_Document_Section
  {
  
  Section_Title: 'Whirlwind Rainbow Serpent',
  Chapter_Title: 'Ancestral Dreaming Texts',
  Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
  Description: "The Whirlwind Rainbow Serpent journeyed from Mangkalbarra in the east to Mirrimirriji in the west. Along the way, encountering various Dreamings and landmarks, he named and shaped the land, facing challenges from other spirits like the Stinking Turtle and Blind Rainbow Serpent. Eventually, he settled at Mirrimirriji.",
  Pages:'512-524',
  Note: 'Yijan: Walalu; Ngalki: Mambaliya; Awara: Massacre Inlet, Calvert River, Robinson River, Foelsche River, Wearyan River, Twenty Mile Flat, Poison Creek, Duck Island and Batten Creek'
  }
);


CREATE (:Text_Document_Section
  {
  
  Section_Title: 'White-Bellied Sea Eagle',
  Chapter_Title: 'Ancestral Dreaming Texts',
  Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
  Description: "Muluwa, significant to Rrumburriya people, holds the Dreaming place of the Wave on its high sand dune. The White-Bellied Sea Eagle's journey across lands—Arnarrijila, Wulibirra—marks sacred sites. She cooked flying-foxes at Kandanbarrawujbi, stayed at Wulibirra, denying feathers to the Wedge-Tailed Eagle. Muluwa and Wulibirra, like brothers, gaze eternally at each other.",
  Pages:'524-530',
  Note: 'Yijan: a-Karnkarnka; Ngalki: Rrumburriya; Awara: east bank of the mouth of the Wearyan River, Cape Vanderlin, and Red Bluff on North Island'
  }
);


CREATE (:Text_Document_Section
  {
  
  Section_Title: 'Women/Mermaids',
  Chapter_Title: 'Ancestral Dreaming Texts',
  Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
  Description: "The Women from Kurrkumala, rising from the sea, traveled carrying their children, led by Maliyawuna and Marawayalu. Carrying the sacred Kunabibi ceremony, they journeyed southward, dancing, placing landmarks, encountering the Whirlwind Rainbow Serpent, and engaging with various Dreamings. Facing disputes, they danced, created landscapes, and settled at Kalabirrngani, chased by a Dingo southwards but returning, jumping into a lagoon where they remain.",
  Pages:'530-537',
  Note: 'Yijan: a-Mararabarna; Ngalki: Rrumburriya; Awara: mouth of the Rosie Creek, Pine Creek down on to Wahallow Station'
  }
);

# %%
# Text_document_chapter

CREATE (:Text_Document_Chapter
    {
    
    Chapter_Title: 'The Country of Yanyuwa Language',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "The summary covers the evolution of the Yanyuwa language, pre and post-contact with non-Aboriginals, including their community today. It delves into their encounter with non-Aboriginals, Borroloola's impact, the influence of the cattle industry, educational policies, and current trends affecting the Yanyuwa language and community.",
    Pages:'1-27',
    Chapter_Number:'1'
    }
);

CREATE (:Text_Document_Chapter
    {
    
    Chapter_Title: 'Recording Yanyuwa: People, Words and Meanings',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "This chapter covers the efforts given by various scholars into the recording of people, words and meanings of the Yanyuwa community.",
    Pages:'28-44',
    Chapter_Number:'2'
    }
);


CREATE (:Text_Document_Chapter
    {
    
    Chapter_Title: 'Yanyuwa Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: 'This chapter covers various Yanyuwa texts written by people from the Yanyuwa community.',
    Pages:'45-351',
    Chapter_Number:'3'
    }
);

CREATE (:Text_Document_Chapter
    {
    
    Chapter_Title: 'Yanyuwa Song Poetry',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "Yanyuwa song poetry encompasses themes like traditional fun songs, historical periods of European contact, land-related songs, wartime reflections, and specific events from the Makassan era to land claims and lullabies.",
    Pages:'352-396',
    Chapter_Number:'4'
    }
);

CREATE (:Text_Document_Chapter
    {
    
    Chapter_Title: 'Ancestral Dreaming Texts',
    Document_Title: 'A Yanyuwa Encyclopaedia Volume 1',
    Description: "The word 'Dreaming' refers to narratives detailing the cosmological forces that shaped and created the Yanyuwa country. These narratives encompass the journeys of Ancestral beings who traveled across the Yanyuwa country, imparting laws and cultural significance. They are seen as crucial by the Yanyuwa people, offering an enchanted insight into the origins and nature of their land.",
    Pages:'352-396',
    Chapter_Number:'5'
    }
);

# %%
# Text_document level

CREATE (:Text_Document
    {
    
    Title: 'Songs from the gulf country: The songs of Yanyuwa family', 
    Year: 2022,
    Authors_and_contributors: '1.Books produced by Fiona Holley and Amanda Kearney; 2. Songs are contributed by various Yanyuwa people.',  
    
    Source_document: 'Gulf Country Song Book Nov 1 2022.pdf', 
    Number_of_pages: 34,
    Data_stored_at: 'https://drive.google.com/file/d/10xUgOyFmwWw6GXk7n_AKxKa3dTiJQwA4/view?usp=drive_link',
    Source_document_type: 'Text data (pdf document)' ,
    
    Authentic_Yanyuwa_source: 'Yes, the songs were composed by people from Yanyuwa community',
    Description: 'This book includes the songs composed by people from Yanyuwa community',
    Topics_and_keywords: 'Traditions, Country, Rules, Customs, Hunting Activities, Food, Land, Migration, Nostalgia, Ownership, Exchanging good'
    }
);


CREATE (:Text_Document
    {
    
    Title: 'Duwarra Wujara Kulu Bujimala: Two Young Men and the Rainbow Serpent', 
    Year:2022,
    Authors_and_contributors: 'Amanda Kearney and Others',
    
    Source_document: 'Duwarra wujara Book Nov 2 2022.pdf', 
    Number_of_pages: 68,
    Data_stored_at: 'https://drive.google.com/file/d/1d5SQQlW8smyw2bTv7N907ud4yHYnGlkJ/view?usp=drive_link',
    Source_document_type: 'Text data (pdf document)' ,
    
    Authentic_Yanyuwa_source: 'The initial story was provided by Pharaoh Lhawulhawu, which was revised to the current version after consulting various members of the Yanyuwa community.',
    Description: 'The story narrates the journey of two young men, Dambulyama from the Rrumburriya clan and Mawurrinya from the Wuyaliya clan, as they travel through their country, encountering significant sites and the Rainbow Serpent, a powerful entity in their culture. The country is named and becomes recognized through this journey. The locations visited are sacred to the Yanyuwa people, tied to the Law, which involves a set of cultural norms, and form a warning narrative to boys undergoing initiation about behaviors they should avoid. The Rainbow Serpent, associated with creating the wet season and linked to initiation ceremonies, watches over the initiates. As the story unfolds, the young men ignore the Law, which dictates what initiates, or daru and later duwarra, should not do, leading to their punishment by the Rainbow Serpent. In the end, the Rainbow Serpent places the two young men on distant islands as a permanent reminder and warning.',
    Topics_and_keywords: 'Law, Journey, Rrumburriya, Wuyaliya, Yanyuwa, Naming, Sacred Sites, Initiation, Daru, Duwarra, Rainbow Serpent, Punishment, Respect, Flying Fox, Cultural Norms, Tidal Wave, Dambulyama, Mawurrinya, Ancestral, Prohibition'
    }
);


CREATE (:Text_Document
    {
    
    Title: 'A-barral kulu Nya-mirningiya/A-barral kulu Mirningiya', 
    English_title:'White Cockatoo and Man',
    Year:'1982',
    Authors_and_contributors: 'Bella Charlie and Jemima Miller',
    
    Source_document: 'A-barral kulu Nya-mirningiyaA-barral kulu Mirningiya [Only Yanyuwa].pdf', 
    Number_of_pages:53 ,
    Data_stored_at: 'https://drive.google.com/file/d/1VyNlJGWX_0JHwO1CB1gCqHSpFkuh8Fkv/view?usp=drive_link',
    Source_document_type: 'Text data (pdf document)',
    
    Authentic_Yanyuwa_source: 'Yes',
    Description: 'Yanyuwa story for children: White Cockatoo and Man (English Translation)',
    Topics_and_keywords: 'TBD'
    }
);


CREATE (:Text_Document
    {
    
    Title: 'Kiya-arri nya-ardu ngamala/ Ka-arri ardu ngamala', 
    Year: 1982,
    Authors_and_contributors: 'Bella Charlie, Jemima Miller and Queenie Simon',   
    
    Source_document: 'Kiya-arri nya-ardu ngamala [Only Yanyuwa].pdf', 
    Number_of_pages: 31,
    Data_stored_at: 'https://drive.google.com/file/d/1ZduKFuxhyUtf3HvYw0pLF1u0XIqT1y7L/view?usp=drive_link',
    Source_document_type: 'Text data (pdf document)',
    
    Authentic_Yanyuwa_source: 'Yes',
    Description: 'Yanyuwa story for children: A boy in the south (English Translation)',
    Topics_and_keywords: 'TBD'
    }
);

CREATE (:Text_Document
    {
    
    Title: 'A Yanyuwa Encyclopaedia Volume 1', 
    Year: 2016,
    Authors_and_contributors: 'Yanyuwa Families and John Bradley incorporating the work of Jean Kirton and Elfreda MacDonald',
    
    Source_document: 'Yanyuwa_Encyclopedia_Volume_1.pdf', 
    Number_of_pages: 593,
    Data_stored_at: 'https://drive.google.com/file/d/1eN8EU0EB_k9wzRuzePW6qiAXFNpnftTL/view?usp=drive_link',
    Source_document_type: 'Text data (pdf document)',
    
    Authentic_Yanyuwa_source: 'It includes a large amount of authentic Yanyuwa texts',
    Description: 'A Yanyuwa Encyclopaedia Volume 1',
    Topics_and_keywords: 'Encyclopedia, Yanyuwa Culture, Grammar, Yanyuwa Text, Yanyuwa Songs, Yanyuwa poetry'
    }
);

CREATE (:Text_Document
    {
    
    Title: 'A Yanyuwa Encyclopaedia Volume 2: Yanyuwa Grammar', 
    Year: 2017,
    Authors_and_contributors: 'Yanyuwa Families and John Bradley incorporating the work of Jean Kirton and Elfreda MacDonald',
    
    Source_document: 'Yanyuwa_Encyclopedia_Volume_2.pdf', 
    Number_of_pages: '1-86',
    Data_stored_at: 'https://drive.google.com/file/d/1ao07HLP5YbSoUsHY_YoAsBNEed0kIWvJ/view?usp=drive_link',
    Source_document_type: 'Text data (pdf document)',
    
    Authentic_Yanyuwa_source: 'No',
    Description: 'This document is the part 1 of the Yanyuwa Encyclopaedia Volume 2, which focuses mainly on the Yanyuwa grammar.',
    Topics_and_keywords: 'Encyclopedia, Yanyuwa Grammar'
    }
);



CREATE (:Text_Document
    {
    
    Title: 'A Yanyuwa Encyclopaedia Volume 2: Yanyuwa–English Dictionary', 
    Year: 2017,
    Authors_and_contributors: 'Yanyuwa Families and John Bradley incorporating the work of Jean Kirton and Elfreda MacDonald',
    
    Source_document: 'Yanyuwa_Encyclopedia_Volume_2.pdf', 
    Number_of_pages: '87-574',
    Data_stored_at: 'https://drive.google.com/file/d/1ao07HLP5YbSoUsHY_YoAsBNEed0kIWvJ/view?usp=drive_link',
    Source_document_type: 'Text data (pdf document)',
    
    Authentic_Yanyuwa_source: 'No',
    Description: 'This document is the part 2 of the Yanyuwa Encyclopaedia Volume 2 (Yanyuwa–English Dictionary).',
    Topics_and_keywords: 'Encyclopedia, Yanyuwa–English Dictionary'
    }
);

CREATE (:Text_Document
    {
    
    Title: 'A Yanyuwa Encyclopaedia Volume 2: English–Yanyuwa Word Finder', 
    Year: 2017,
    Authors_and_contributors: 'Yanyuwa Families and John Bradley incorporating the work of Jean Kirton and Elfreda MacDonald',
    
    Source_document: 'Yanyuwa_Encyclopedia_Volume_2.pdf', 
    Number_of_pages: '575-703',
    Data_stored_at: 'https://drive.google.com/file/d/1ao07HLP5YbSoUsHY_YoAsBNEed0kIWvJ/view?usp=drive_link',
    Source_document_type: 'Text data (pdf document)',
    
    Authentic_Yanyuwa_source: 'No',
    Description: 'This document is the part 3 of the Yanyuwa Encyclopaedia Volume 2 (English–Yanyuwa Word Finder)',
    Topics_and_keywords: 'Encyclopedia, English–Yanyuwa Word Finder'
    }
);

CREATE (:Text_Document
    {
    
    Title: 'Further Aspects of the Grammar of Yanyuwa, Northern Australia', 
    Year: 1996,
    Authors_and_contributors: 'Jean Kirton and Bella Charlie',   
    
    Source_document: 'Further aspects of the grammar of Yanyuwa, Northern Australia [Yanyuwa and English].pdf', 
    Number_of_pages: 230,
    Data_stored_at: 'https://drive.google.com/file/d/1zuwt98i8TNO2_VWUy-4vRm4gdy4_Kyuk/view?usp=drive_link',
    Source_document_type: 'Text data (pdf document)',
    
    Authentic_Yanyuwa_source: 'No',
    Description: 'About Yanyuwa grammar',
    Topics_and_keywords: 'Grammar'
    }
);

CREATE (:Text_Document
    {
    
    Title: 'Yanyuwa Wuka: Language from yanyuwa country', 
    Year: 1992,
    Authors_and_contributors: 'John Bradley, Jean Kirton and the Yanyuwa Community',  
    
    Source_document: 'Yanyuwa Wuka - Language from yanyuwa country [Yanyuwa and English].pdf', 
    Number_of_pages: 636,
    Data_stored_at: 'https://drive.google.com/file/d/1W9TKn-zj6LZ-DhX-ISIDwZ3NIjsKord0/view?usp=drive_link',
    Source_document_type: 'Text data (pdf document)',
    
    Authentic_Yanyuwa_source: 'No.',
    Description: 'An old version of the Yanyuwa encyclopedia 1&2',
    Topics_and_keywords: 'TBD'
    }
);

CREATE (:Video_Document
    {
    
    Title: 'Duwarra Wujara Kulu Bujimala: Two Young Men and the Rainbow Serpent', 
    Year: 2022,
    Authors_and_contributors: 'Many people contributed their efforts into the productiin of this video',    
    
    Source_document: 'Duwarra Wujara (Two Young Men).mp4', 
    Video_length: '27:08' ,
    Data_stored_at: 'https://drive.google.com/file/d/1xDw6-vm5W-LGADzCyk7k9toUEo5opqv7/view?usp=drive_link',
    Source_document_type: 'Video data',
    
    Authentic_Yanyuwa_source: 'The initial story was provided by Pharaoh Lhawulhawu, which was revised to the current version after consulting various members of the Yanyuwa community.',
    Description: 'The story narrates the journey of two young men, Dambulyama from the Rrumburriya clan and Mawurrinya from the Wuyaliya clan, as they travel through their country, encountering significant sites and the Rainbow Serpent, a powerful entity in their culture. The country is named and becomes recognized through this journey. The locations visited are sacred to the Yanyuwa people, tied to the Law, which involves a set of cultural norms, and form a warning narrative to boys undergoing initiation about behaviors they should avoid. The Rainbow Serpent, associated with creating the wet season and linked to initiation ceremonies, watches over the initiates. As the story unfolds, the young men ignore the Law, which dictates what initiates, or daru and later duwarra, should not do, leading to their punishment by the Rainbow Serpent. In the end, the Rainbow Serpent places the two young men on distant islands as a permanent reminder and warning.',
    Topics_and_keywords: 'Law, Journey, Rrumburriya, Wuyaliya, Yanyuwa, Naming, Sacred Sites, Initiation, Daru, Duwarra, Rainbow Serpent, Punishment, Respect, Flying Fox, Cultural Norms, Tidal Wave, Dambulyama, Mawurrinya, Ancestral, Prohibition'
    }
);


CREATE (:Video_Document
    {
    
    Title: 'Turtle hunting, Tent boxing and Aeroplane Dance Documentary', 
    Year: 1993,
    Authors_and_contributors: 'Many people contributed theire efforts to the productiin of this video',    
    
    Source_document: 'Turtle hunting, tent boxing and Aeroplane Dance.m4v', 
    Video_length: '01:27:21' ,
    Data_stored_at: 'https://drive.google.com/file/d/1GJY_h7Q8StOv9gzqzhv_O1_yb1pLIn3d/view?usp=drive_link',
    Source_document_type: 'Video data' ,
    
    Authentic_Yanyuwa_source: 'This video recorded a lot of traditional activities/conversations of people from the Yanyuwa community.',
    Description: 'This video records the activities of Yanyuwa people about their turtle hunting, tent boxing and Aeroplane Dance.',
    Topics_and_keywords: 'Turtle hunting, Tent boxing, Aeroplane Dance, Custom'
    }
);



CREATE (:Video_Document
    {
    
    Title: 'Yanyuwa Culture Documentary and Journey East', 
    Year: 1989,
    Authors_and_contributors: 'DEBBIE SONENBERG',    
    
    Source_document: 'Yanyuwa Culture Documentary and Journey East.m4v', 
    Video_length:'01:40:08' ,
    Data_stored_at: 'https://drive.google.com/file/d/15qNam05vuvyD-cM4UtVM_gQE5HsO7t4m/view?usp=drive_link',
    Source_document_type: 'Video data' ,
    
    Authentic_Yanyuwa_source: 'The film was made at the request of the Yanyuwa people.',
    Description: 'In July 1985, the Yanyuwa and Mara people of Australia documented theirtraditional relationship with the sea, particularly the hunting of Dugongs and sea turtles. These marine creatures hold economic and cultural importance for the people who traditionally inhabited the Swedward Paliu Islands. The Yanyuwa and Mara people have a detailed understanding and spiritual connection with these animals, using 22 different names to classify Dugongs and 23 for green turtles. Despite the modernization, these traditional seafood hunting practices have continued, albeit with the replacement of canoes with aluminium dinghies and the replacement of handmade ropes with commercially made ones. The Yanyuwa and Mara people preserve their hunting traditions in songs and artifacts that detail the paths of animal dreamings or ancient spiritual journeys. The 1985 film aimed to record these traditions, both for the Yanyuwa and Mara community and outsiders.',
    Topics_and_keywords: 'Yanyuwa and Mara people, Film, Dugong, Sea turtle, Traditional law, Economy, Swedward Paliu Islands, Limon, MacArthur and Wirian rivers, Borrolula, Gulf of Carpentaria, Seagrasses, Conservation, Green turtle, Hawksbill, Fatback, Community, Hunting, Conservation Commission rangers, Ijang songs, Dreamings'
    }
);


CREATE (:Video_Document
    {
    
    Title: 'Songs from the gulf country', 
    Year: 2022,
    Authors_and_contributors: 'This video was the combined efforts from many people and organizations',    
    
    Source_document: 'Songs from the Gulf Country - h264.mov', 
    Video_length:'08:50',
    Data_stored_at: 'https://drive.google.com/file/d/1cd2GSJC7lFbP56KgPbGexbVxhrIVrucM/view?usp=drive_link',
    Source_document_type: 'Video data' ,
    
    Authentic_Yanyuwa_source: 'Yes, the songs were composed by people from Yanyuwa community',
    Description: 'This video includes the songs composed by people from Yanyuwa community',
    Topics_and_keywords: 'Traditions, Country, Rules, Customs, Hunting Activities, Food, Land, Migration, Nostalgia, Ownership, Exchanging good'
    }
);

# %%
import pandas as pd

df = pd.read_excel('audio.xlsx')


res = []
for i in range(len(df)):
    record = df.iloc[i].to_dict()
    #print(record)
    code = r"""

        CREATE (:Audio_Document
            {

            Title: '<TITLE>', 
            Year: '<YEAR>',
            Authors_and_contributors: '<AUTHOR>',    

            Source_document: 'Bradley/<NUMBER>.mp3', 
            Audio_length: '<LENGTH>',
            Data_stored_at: 'https://drive.google.com/drive/folders/13q40O8EgTQxujxh3SZPuac3CX4LDSMCU?usp=drive_link',
            Source_document_type: 'Audio data' ,

            Authentic_Yanyuwa_source: '',
            Description: '<DESCRIPTION>',
            Topics_and_keywords: ''
            }
        )

    """.replace('<TITLE>', str(record['Label'])).replace('<YEAR>', str(record['Date'])).replace('<AUTHOR>', str(record['Participants'])).replace('<NUMBER>', '0'+str(record['No.'])[-2:]).replace('<LENGTH>', str( record['Time'])).replace('<DESCRIPTION>', str(record['Description']))
    
    
    #format(, , , , record['Description'])
    res.append(code)


for e in res:
    print(e+';')
    print('\n')
# Out:
#         CREATE (:Audio_Document
#             {
#
#             Title: 'Kujika',
#             Year: '1980',
#             Authors_and_contributors: 'Dinny McDinny',
#
#             Source_document: 'Bradley/01.mp3',
#             Audio_length: '57:15',
#             Data_stored_at: 'https://drive.google.com/drive/folders/13q40O8EgTQxujxh3SZPuac3CX4LDSMCU?usp=drive_link',
#             Source_document_type: 'Audio data' ,
#
#             Authentic_Yanyuwa_source: '',
#             Description: 'Topside Mambaliya kujika',
#             Topics_and_keywords: ''
#             }
#         )
#
#     ;
#
#
#
#
#         CREATE (:Audio_Document
#             {
#
#             Title: 'Stories- family and country ',
#             Year: '1988',
#             Authors_and_contributors: 'Jerry Brown,Isaac Isaac,Ron Rickett',
#
#             Source_document: 'Bradley/02.mp3',
#             Audio_length: '25:27',
# ...
