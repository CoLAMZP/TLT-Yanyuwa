# %% [raw]
# ## Terns at Yinijini
#
# Kinyamba-wunkulma
# Kiwa-wani
# Jarranymantharra
# Yinijini

# %%
CREATE (:Word
    {
    Yanyuwa: 'jarranymantharra',
    POS:'intransitive verb ',
    In_English: ' 1) calling out in anger; 2) inciting, saying things inclined to lead to a fight.',
    Antonym: '',
    Synonym: '',
    Hypernymy: '',
    Hyponymy: '',
    Root: '',
    Stem: ''
    }
);
MATCH (a:Sentence {Sequence_number: 1, Source_Paragraph: 1,  Source: 'Terns at Yinijini'}) , (b:Word {Yanyuwa: 'jarranymantharra'}), 
MERGE (a)-[r:Sentence_Word_Relation]->(b);
